# %% [markdown]
# # Credit Risk Modeling Project

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score
from scipy.stats import chi2_contingency
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split
import warnings
import os

pd.set_option('display.float_format', lambda x: '{:.2f}'.format(x))
np.set_printoptions(suppress=True)

# %% [markdown]
# ### Load Data

# %%
df_customers= pd.read_csv("C:/Users/debas/Downloads/Project2_DataCollection_Resources/customers.csv") 
df_loans= pd.read_csv("C:/Users/debas/Downloads/Project2_DataCollection_Resources/loans.csv") 
df_bureau= pd.read_csv("C:/Users/debas/Downloads/Project2_DataCollection_Resources/bureau_data.csv")

# %%
df_customers.shape, df_loans.shape, df_bureau.shape
# Out:
# ((50000, 12), (50000, 15), (50000, 8))

# %%
df_customers.head()
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
# 3  C00004   55      F         Single     Self-Employed  3547000
# 4  C00005   37      M        Married          Salaried  3432000
#
#    number_of_dependants residence_type  years_at_current_address       city  \
# 0                     3          Owned                        27      Delhi
# 1                     3          Owned                         4    Chennai
# 2                     3          Owned                        24    Kolkata
# 3                     1          Owned                        15  Bangalore
# 4                     3          Owned                        28       Pune
#
#          state  zipcode
# 0        Delhi   110001
# 1   Tamil Nadu   600001
# 2  West Bengal   700001
# 3    Karnataka   560001
# 4  Maharashtra   411001

# %%
df_loans.head()
# Out:
#   loan_id cust_id loan_purpose  loan_type  sanction_amount  loan_amount  \
# 0  L00001  C00001         Auto    Secured          3004000      2467000
# 1  L00002  C00002         Home    Secured          4161000      3883000
# 2  L00003  C00003     Personal  Unsecured          2401000      2170000
# 3  L00004  C00004     Personal  Unsecured          2345000      1747000
# 4  L00005  C00005         Auto    Secured          4647000      4520000
#
#    processing_fee     gst  net_disbursement  loan_tenure_months  \
# 0        49340.00  444060           1973600                  33
# 1        77660.00  698940           3106400                  30
# 2        43400.00  390600           1736000                  21
# 3        34940.00  314460           1397600                   6
# 4        90400.00  813600           3616000                  28
#
#    principal_outstanding  bank_balance_at_application disbursal_date  \
# 0                1630408                       873386     2019-07-24
# 1                 709309                       464100     2019-07-24
# 2                1562399                      1476042     2019-07-24
# 3                1257839                      1031094     2019-07-24
# 4                1772334                      1032458     2019-07-24
#
#   installment_start_dt  default
# 0           2019-08-10    False
# 1           2019-08-15    False
# 2           2019-08-21    False
# 3           2019-08-09    False
# 4           2019-08-02    False

# %%
df= pd.merge(df_customers, df_loans, on='cust_id')
df.head(3)
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
#
#    number_of_dependants residence_type  years_at_current_address     city  \
# 0                     3          Owned                        27    Delhi
# 1                     3          Owned                         4  Chennai
# 2                     3          Owned                        24  Kolkata
#
#    ... loan_amount  processing_fee     gst net_disbursement  \
# 0  ...     2467000        49340.00  444060          1973600
# 1  ...     3883000        77660.00  698940          3106400
# 2  ...     2170000        43400.00  390600          1736000
#
#   loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# 0                 33                1630408                       873386
# 1                 30                 709309                       464100
# 2                 21                1562399                      1476042
#
#    disbursal_date  installment_start_dt  default
# 0      2019-07-24            2019-08-10    False
# 1      2019-07-24            2019-08-15    False
# 2      2019-07-24            2019-08-21    False
#
# [3 rows x 26 columns]

# %%
df=pd.merge(df, df_bureau)
df.head(3)           ### Final data frame merged 3 datasets
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
#
#    number_of_dependants residence_type  years_at_current_address     city  \
# 0                     3          Owned                        27    Delhi
# 1                     3          Owned                         4  Chennai
# 2                     3          Owned                        24  Kolkata
#
#    ... disbursal_date  installment_start_dt default number_of_open_accounts  \
# 0  ...     2019-07-24            2019-08-10   False                       1
# 1  ...     2019-07-24            2019-08-15   False                       3
# 2  ...     2019-07-24            2019-08-21   False                       2
#
#   number_of_closed_accounts  total_loan_months  delinquent_months  total_dpd  \
# 0                         1                 42                  0          0
# 1                         1                 96                 12         60
# 2                         1                 82                 24        147
#
#    enquiry_count  credit_utilization_ratio
# 0              3                         7
# 1              5                         4
# 2              6                        58
#
# [3 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 0 to 49999
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cust_id                      50000 non-null  object
#  1   age                          50000 non-null  int64
#  2   gender                       50000 non-null  object
#  3   marital_status               50000 non-null  object
#  4   employment_status            50000 non-null  object
#  5   income                       50000 non-null  int64
#  6   number_of_dependants         50000 non-null  int64
#  7   residence_type               49938 non-null  object
#  8   years_at_current_address     50000 non-null  int64
#  9   city                         50000 non-null  object
#  10  state                        50000 non-null  object
#  11  zipcode                      50000 non-null  int64
#  12  loan_id                      50000 non-null  object
#  13  loan_purpose                 50000 non-null  object
#  14  loan_type                    50000 non-null  object
#  15  sanction_amount              50000 non-null  int64
#  16  loan_amount                  50000 non-null  int64
#  17  processing_fee               50000 non-null  float64
#  18  gst                          50000 non-null  int64
#  19  net_disbursement             50000 non-null  int64
#  20  loan_tenure_months           50000 non-null  int64
#  21  principal_outstanding        50000 non-null  int64
#  22  bank_balance_at_application  50000 non-null  int64
#  23  disbursal_date               50000 non-null  object
#  24  installment_start_dt         50000 non-null  object
#  25  default                      50000 non-null  bool
#  26  number_of_open_accounts      50000 non-null  int64
#  27  number_of_closed_accounts    50000 non-null  int64
#  28  total_loan_months            50000 non-null  int64
#  29  delinquent_months            50000 non-null  int64
#  30  total_dpd                    50000 non-null  int64
#  31  enquiry_count                50000 non-null  int64
#  32  credit_utilization_ratio     50000 non-null  int64
# dtypes: bool(1), float64(1), int64(19), object(12)
# memory usage: 12.6+ MB

# %%
df.isna().sum().sum()
# Out:
# 62

# %%
df['default']=df['default'].astype(int)
df.default.value_counts()
# Out:
# 0    45703
# 1     4297
# Name: default, dtype: int64

# %% [markdown]
# default is a target variable and we can see some class imbalance here. We will address it later on.

# %%
df.head(2)
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
#
#    number_of_dependants residence_type  years_at_current_address     city  \
# 0                     3          Owned                        27    Delhi
# 1                     3          Owned                         4  Chennai
#
#    ... disbursal_date  installment_start_dt default number_of_open_accounts  \
# 0  ...     2019-07-24            2019-08-10       0                       1
# 1  ...     2019-07-24            2019-08-15       0                       3
#
#   number_of_closed_accounts  total_loan_months  delinquent_months  total_dpd  \
# 0                         1                 42                  0          0
# 1                         1                 96                 12         60
#
#    enquiry_count  credit_utilization_ratio
# 0              3                         7
# 1              5                         4
#
# [2 rows x 33 columns]

# %% [markdown]
# ### Train Test split

# %% [markdown]
# We perform train test split before doing EDA to prevent data leakage. We don't want test set (which is part of the entire dataset) to influence EDA or any decisions on feature engineering.

# %%
X= df.drop("default", axis="columns")
y=df['default']

X_train, X_test, y_train, y_test= train_test_split(X,y, stratify=y, test_size=0.25, random_state=42)

df_train= pd.concat([X_train, y_train], axis='columns')
df_test= pd.concat([X_test, y_test], axis='columns')

df_train.head()
# Out:
#       cust_id  age gender marital_status employment_status    income  \
# 12746  C12747   59      M        Married     Self-Employed  11327000
# 32495  C32496   44      F         Single          Salaried    715000
# 43675  C43676   38      M         Single          Salaried   3195000
# 9040   C09041   42      M        Married          Salaried   1500000
# 13077  C13078   58      M        Married     Self-Employed   1817000
#
#        number_of_dependants residence_type  years_at_current_address  \
# 12746                     3          Owned                        30
# 32495                     0          Owned                        27
# 43675                     0       Mortgage                        26
# 9040                      2       Mortgage                        30
# 13077                     4          Owned                        29
#
#             city  ... disbursal_date  installment_start_dt  \
# 12746  Hyderabad  ...     2020-10-31            2020-11-11
# 32495     Mumbai  ...     2022-10-22            2022-10-27
# 43675    Chennai  ...     2023-12-04            2023-12-29
# 9040   Bangalore  ...     2020-06-18            2020-07-07
# 13077       Pune  ...     2020-11-12            2020-12-07
#
#       number_of_open_accounts number_of_closed_accounts total_loan_months  \
# 12746                       4                         2               152
# 32495                       3                         1               160
# 43675                       1                         1                54
# 9040                        3                         0                76
# 13077                       1                         2                60
#
#        delinquent_months  total_dpd  enquiry_count  credit_utilization_ratio  \
# 12746                 20        118              4                        36
# 32495                 10         62              5                         5
# 43675                 12         67              4                         0
# 9040                   0          0              8                        87
# 13077                  0          0              1                        71
#
#        default
# 12746        0
# 32495        0
# 43675        0
# 9040         0
# 13077        0
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (50000, 33)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((37500, 32), (12500, 32), (37500,), (12500,))

# %% [markdown]
# <h3 align="center" style="color:blue">Data Cleaning</h3>

# %% [markdown]
# ### Handle Missing & Duplicate Values
# to avoid data leakage and exploration we now will look into train set only

# %%
df_train.shape, df_test.shape
# Out:
# ((37500, 33), (12500, 33))

# %%
df_train.isna().sum()
# Out:
# cust_id                         0
# age                             0
# gender                          0
# marital_status                  0
# employment_status               0
# income                          0
# number_of_dependants            0
# residence_type                 47
# years_at_current_address        0
# city                            0
# state                           0
# zipcode                         0
# loan_id                         0
# loan_purpose                    0
# loan_type                       0
# sanction_amount                 0
# loan_amount                     0
# processing_fee                  0
# gst                             0
# net_disbursement                0
# loan_tenure_months              0
# principal_outstanding           0
# bank_balance_at_application     0
# disbursal_date                  0
# installment_start_dt            0
# number_of_open_accounts         0
# number_of_closed_accounts       0
# total_loan_months               0
# delinquent_months               0
# total_dpd                       0
# enquiry_count                   0
# credit_utilization_ratio        0
# default                         0
# dtype: int64

# %%
df_train.residence_type.unique()
# Out:
# array(['Owned', 'Mortgage', 'Rented', nan], dtype=object)

# %%
mode_residence= df_train.residence_type.mode()[0]
mode_residence
# Out:
# 'Owned'

# %%
df_train.residence_type.fillna(mode_residence, inplace=True)
df_train.residence_type.unique()
# Out:
# array(['Owned', 'Mortgage', 'Rented'], dtype=object)

# %%
df_test.residence_type.fillna(mode_residence, inplace=True)

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
df_train.isna().sum()
# Out:
# cust_id                        0
# age                            0
# gender                         0
# marital_status                 0
# employment_status              0
# income                         0
# number_of_dependants           0
# residence_type                 0
# years_at_current_address       0
# city                           0
# state                          0
# zipcode                        0
# loan_id                        0
# loan_purpose                   0
# loan_type                      0
# sanction_amount                0
# loan_amount                    0
# processing_fee                 0
# gst                            0
# net_disbursement               0
# loan_tenure_months             0
# principal_outstanding          0
# bank_balance_at_application    0
# disbursal_date                 0
# installment_start_dt           0
# number_of_open_accounts        0
# number_of_closed_accounts      0
# total_loan_months              0
# delinquent_months              0
# total_dpd                      0
# enquiry_count                  0
# credit_utilization_ratio       0
# default                        0
# dtype: int64

# %%
df_train.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'income', 'number_of_dependants', 'residence_type',
#        'years_at_current_address', 'city', 'state', 'zipcode', 'loan_id',
#        'loan_purpose', 'loan_type', 'sanction_amount', 'loan_amount',
#        'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months',
#        'principal_outstanding', 'bank_balance_at_application',
#        'disbursal_date', 'installment_start_dt', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
#        'total_dpd', 'enquiry_count', 'credit_utilization_ratio', 'default'],
#       dtype='object')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37500 entries, 12746 to 37784
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cust_id                      37500 non-null  object
#  1   age                          37500 non-null  int64
#  2   gender                       37500 non-null  object
#  3   marital_status               37500 non-null  object
#  4   employment_status            37500 non-null  object
#  5   income                       37500 non-null  int64
#  6   number_of_dependants         37500 non-null  int64
#  7   residence_type               37500 non-null  object
#  8   years_at_current_address     37500 non-null  int64
#  9   city                         37500 non-null  object
#  10  state                        37500 non-null  object
#  11  zipcode                      37500 non-null  int64
#  12  loan_id                      37500 non-null  object
#  13  loan_purpose                 37500 non-null  object
#  14  loan_type                    37500 non-null  object
#  15  sanction_amount              37500 non-null  int64
#  16  loan_amount                  37500 non-null  int64
#  17  processing_fee               37500 non-null  float64
#  18  gst                          37500 non-null  int64
#  19  net_disbursement             37500 non-null  int64
#  20  loan_tenure_months           37500 non-null  int64
#  21  principal_outstanding        37500 non-null  int64
#  22  bank_balance_at_application  37500 non-null  int64
#  23  disbursal_date               37500 non-null  object
#  24  installment_start_dt         37500 non-null  object
#  25  number_of_open_accounts      37500 non-null  int64
#  26  number_of_closed_accounts    37500 non-null  int64
#  27  total_loan_months            37500 non-null  int64
#  28  delinquent_months            37500 non-null  int64
#  29  total_dpd                    37500 non-null  int64
#  30  enquiry_count                37500 non-null  int64
#  31  credit_utilization_ratio     37500 non-null  int64
#  32  default                      37500 non-null  int32
# dtypes: float64(1), int32(1), int64(19), object(12)
# memory usage: 9.6+ MB

# %%
# check how many columns are categorical
for i in df_train.columns:
    if df_train[i].dtype == 'object':
        print(i)
# Out:
# cust_id
# gender
# marital_status
# employment_status
# residence_type
# city
# state
# loan_id
# loan_purpose
# loan_type
# disbursal_date
# installment_start_dt

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Assuming df is your DataFrame and 'default' is your target variable
for i in ['gender', 'marital_status', 'employment_status', 'residence_type', 'city', 'state', 'loan_purpose', 'loan_type']:
    # Create a contingency table
    contingency_table = pd.crosstab(df[i], df['default'])
    
    # Perform the Chi-Square test
    chi2, pval, _, _ = chi2_contingency(contingency_table)
    
    # Print the variable name and its p-value
    print(i, '---', pval)
# Out:
# gender --- 0.2188561624385111
# marital_status --- 0.006080465082650257
# employment_status --- 0.000652993685198681
# residence_type --- 6.217142617273878e-238
# city --- 0.7903291274966309
# state --- 0.7636613836574949
# loan_purpose --- 0.0
# loan_type --- 5.8437751376967325e-124

# %%
columns_continuous = ['age', 'income', 'number_of_dependants', 'years_at_current_address', 
                      'sanction_amount', 'loan_amount', 'processing_fee', 'gst', 'net_disbursement', 
                      'loan_tenure_months','principal_outstanding', 'bank_balance_at_application',
                      'number_of_open_accounts','number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
                       'total_dpd', 'enquiry_count', 'credit_utilization_ratio']

columns_categorical = ['gender', 'marital_status', 'employment_status', 'residence_type', 'city', 
                       'state', 'zipcode', 'loan_purpose', 'loan_type', 'default']

# %% [markdown]
# ### Box plot to visualize outliers
#
# box plot for continuous features

# %%
num_plots = len(columns_continuous)
num_cols = 4  # Number of plots per row
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the axes array for easier indexing

for i, col in enumerate(columns_continuous):
    sns.boxplot(x=df_train[col], ax=axes[i])
    axes[i].set_title(col)  # Set the title to the name of the variable

# If there are any empty plots (if the number of plots isn't a perfect multiple of num_cols), hide the axes
for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Histogram plot

# %%
num_plots = len(columns_continuous)
num_cols = 4  # Number of plots per row
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the axes array for easier indexing

for i, col in enumerate(columns_continuous):
    sns.histplot(df_train[col], ax=axes[i])
    axes[i].set_title(col)  # Set the title to the name of the variable

# If there are any empty plots (if the number of plots isn't a perfect multiple of num_cols), hide the axes
for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Outlier Removal: Processing Fee

# %%
df_train.processing_fee.describe()
# Out:
# count     37500.00
# mean      80290.68
# std      113128.14
# min           0.00
# 25%       19220.00
# 50%       44600.00
# 75%       92420.00
# max     5293543.52
# Name: processing_fee, dtype: float64

# %%
df_train[df_train.processing_fee == df_train.processing_fee.max()][["loan_amount", "processing_fee"]]
# Out:
#       loan_amount  processing_fee
# 9898      3626000      5293543.52

# %% [markdown]
# HERE clearly processing fee cannot be larger than loan amount so there is some error

# %%
df_train[df_train.processing_fee > df_train.loan_amount][["loan_amount", "processing_fee"]]
# Out:
#        loan_amount  processing_fee
# 23981      2234000      2669791.02
# 28174       966000      1214492.67
# 47089      1738000      1858964.77
# 29305      2616000      3036378.01
# 9898       3626000      5293543.52

# %% [markdown]
# these are clearly outlliers, business team said that processing fee should be around 3%

# %%
df_train[(df_train.processing_fee / df_train.loan_amount) >0.03][["loan_amount", "processing_fee"]]
# Out:
#        loan_amount  processing_fee
# 23981      2234000      2669791.02
# 28174       966000      1214492.67
# 47089      1738000      1858964.77
# 29305      2616000      3036378.01
# 9898       3626000      5293543.52

# %% [markdown]
# we will remove these 5 records

# %%
df_train_1 = df_train[df_train.processing_fee/df_train.loan_amount<0.03].copy()
df_train_1[(df_train_1.processing_fee/df_train_1.loan_amount)>0.03][["loan_amount","processing_fee"]]
# Out:
# Empty DataFrame
# Columns: [loan_amount, processing_fee]
# Index: []

# %%
df_train_1.shape
# Out:
# (37488, 33)

# %%
### same for test dataset

df_test = df_test[df_test.processing_fee/df_test.loan_amount<0.03].copy()
df_test.shape
# Out:
# (12497, 33)

# %% [markdown]
#  ### Analyze Categorical Columns¶

# %%
columns_categorical
# Out:
# ['gender',
#  'marital_status',
#  'employment_status',
#  'residence_type',
#  'city',
#  'state',
#  'zipcode',
#  'loan_purpose',
#  'loan_type',
#  'default']

# %%
# Create a dictionary to store the results
chi2_results = {}

# Loop through each categorical column
for column in columns_categorical:
    # Create a contingency table
    contingency_table = pd.crosstab(df[column], df['default'])
    
    # Perform the Chi-Square test
    chi2_stat, p_value, dof, expected = chi2_contingency(contingency_table)
    
    # Store the results
    chi2_results[column] = {
        'chi2_stat': chi2_stat,
        'p_value': p_value,
        'dof': dof,
        'expected': expected
    }

# Display the results
for column, result in chi2_results.items():
    print(f"Column: {column}")
    print(f"Chi-Square Statistic: {result['chi2_stat']}")
    print(f"P-Value: {result['p_value']}")
    print(f"Degrees of Freedom: {result['dof']}")
    print(f"Expected Frequencies Table:\n{result['expected']}\n")
# Out:
# Column: gender
# Chi-Square Statistic: 1.5118555609221527
# P-Value: 0.2188561624385111
# Degrees of Freedom: 1
# Expected Frequencies Table:
# [[18291.25466  1719.74534]
#  [27411.74534  2577.25466]]
#
# Column: marital_status
# Chi-Square Statistic: 7.526300286204689
# P-Value: 0.006080465082650257
# Degrees of Freedom: 1
# Expected Frequencies Table:
# [[25090.947  2359.053]
#  [20612.053  1937.947]]
#
# Column: employment_status
# Chi-Square Statistic: 11.618490705430313
# P-Value: 0.000652993685198681
# Degrees of Freedom: 1
# Expected Frequencies Table:
# [[16285.80702  1531.19298]
#  [29417.19298  2765.80702]]
#
# Column: residence_type
# Chi-Square Statistic: 1092.3758834353448
# P-Value: 6.217142617273878e-238
# Degrees of Freedom: 2
# Expected Frequencies Table:
# [[10802.25075093  1016.74924907]
#  [25808.77880572  2429.22119428]
#  [ 9030.97044335   850.02955665]]
#
# Column: city
# Chi-Square Statistic: 5.483085965710657
# P-Value: 0.7903291274966309
# Degrees of Freedom: 9
# Expected Frequencies Table:
# [[4554.76098  428.23902]
#  [4583.09684  430.90316]
#  [4546.53444  427.46556]
#  [4534.65166  426.34834]
#  [4591.32338  431.67662]
#  [4659.87788  438.12212]
#  [4568.47188  429.52812]
#  [4522.76888  425.23112]
#  [4599.54992  432.45008]
#  [4541.96414  427.03586]]
#
# Column: state
# Chi-Square Statistic: 4.942899005592272
# P-Value: 0.7636613836574949
# Degrees of Freedom: 8
# Expected Frequencies Table:
# [[4534.65166  426.34834]
#  [4554.76098  428.23902]
#  [4583.09684  430.90316]
#  [9141.51406  859.48594]
#  [4659.87788  438.12212]
#  [4546.53444  427.46556]
#  [4591.32338  431.67662]
#  [4522.76888  425.23112]
#  [4568.47188  429.52812]]
#
# Column: zipcode
# Chi-Square Statistic: 5.483085965710657
# P-Value: 0.7903291274966309
# Degrees of Freedom: 9
# Expected Frequencies Table:
# [[4534.65166  426.34834]
#  [4522.76888  425.23112]
#  [4659.87788  438.12212]
#  [4554.76098  428.23902]
#  [4599.54992  432.45008]
#  [4541.96414  427.03586]
#  [4591.32338  431.67662]
#  [4583.09684  430.90316]
#  [4546.53444  427.46556]
#  [4568.47188  429.52812]]
#
# Column: loan_purpose
# Chi-Square Statistic: 1533.7134879565895
# P-Value: 0.0
# Degrees of Freedom: 4
# Expected Frequencies Table:
# [[ 9082.10016   853.89984]
#  [ 6907.55142   649.44858]
#  [13736.49368  1291.50632]
#  [   20.10932     1.89068]
#  [15956.74542  1500.25458]]
#
# Column: loan_type
# Chi-Square Statistic: 560.7259829435119
# P-Value: 5.8437751376967325e-124
# Degrees of Freedom: 1
# Expected Frequencies Table:
# [[29726.14526  2794.85474]
#  [15976.85474  1502.14526]]
#
# Column: default
# Chi-Square Statistic: 49987.270765050234
# P-Value: 0.0
# Degrees of Freedom: 1
# Expected Frequencies Table:
# [[41775.28418  3927.71582]
#  [ 3927.71582   369.28418]]

# %%
for col in columns_categorical:
    print(col, "-->", df_train_1[col].unique())
# Out:
# gender --> ['M' 'F']
# marital_status --> ['Married' 'Single']
# employment_status --> ['Self-Employed' 'Salaried']
# residence_type --> ['Owned' 'Mortgage' 'Rented']
# city --> ['Hyderabad' 'Mumbai' 'Chennai' 'Bangalore' 'Pune' 'Kolkata' 'Ahmedabad'
#  'Delhi' 'Lucknow' 'Jaipur']
# state --> ['Telangana' 'Maharashtra' 'Tamil Nadu' 'Karnataka' 'West Bengal'
#  'Gujarat' 'Delhi' 'Uttar Pradesh' 'Rajasthan']
# zipcode --> [500001 400001 600001 560001 411001 700001 380001 110001 226001 302001]
# loan_purpose --> ['Home' 'Education' 'Personal' 'Auto' 'Personaal']
# loan_type --> ['Secured' 'Unsecured']
# default --> [0 1]

# %% [markdown]
# ##we can see here the loan purpose column needs cleaning as it has personal and personaal

# %% [markdown]
# ### Fix Errors in Loan Purpose Column

# %%
df_train_1['loan_purpose'] = df_train_1['loan_purpose'].replace('Personaal', 'Personal')
df_train_1['loan_purpose'].unique()
# Out:
# array(['Home', 'Education', 'Personal', 'Auto'], dtype=object)

# %%
df_test['loan_purpose'] = df_test['loan_purpose'].replace('Personaal', 'Personal')
df_test['loan_purpose'].unique()
# Out:
# array(['Home', 'Education', 'Auto', 'Personal'], dtype=object)

# %%
### How about checking gst column it should not be greater than 20%

df_train[(df_train.gst/df_train.loan_amount)>0.18]
# Out:
# Empty DataFrame
# Columns: [cust_id, age, gender, marital_status, employment_status, income, number_of_dependants, residence_type, years_at_current_address, city, state, zipcode, loan_id, loan_purpose, loan_type, sanction_amount, loan_amount, processing_fee, gst, net_disbursement, loan_tenure_months, principal_outstanding, bank_balance_at_application, disbursal_date, installment_start_dt, number_of_open_accounts, number_of_closed_accounts, total_loan_months, delinquent_months, total_dpd, enquiry_count, credit_utilization_ratio, default]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# we got no such record

# %% [markdown]
# <h3 style="color:blue" align="center">Exploratory Data Analysis</h3>

# %%
columns_continuous
# Out:
# ['age',
#  'income',
#  'number_of_dependants',
#  'years_at_current_address',
#  'sanction_amount',
#  'loan_amount',
#  'processing_fee',
#  'gst',
#  'net_disbursement',
#  'loan_tenure_months',
#  'principal_outstanding',
#  'bank_balance_at_application',
#  'number_of_open_accounts',
#  'number_of_closed_accounts',
#  'total_loan_months',
#  'delinquent_months',
#  'total_dpd',
#  'enquiry_count',
#  'credit_utilization_ratio']

# %%
df_train_1.groupby("default")['age'].describe()
# Out:
#            count  mean  std   min   25%   50%   75%   max
# default
# 0       34265.00 39.77 9.88 18.00 33.00 40.00 46.00 70.00
# 1        3223.00 37.12 9.29 18.00 31.00 37.00 44.00 70.00

# %% [markdown]
# **Insights**
#
# 1. Average age in the default group is little less (37.12) than the average (39.7) of the group that did not default
# 1. Variability (standard deviation) is mostly similar in both the groups
# 1. Both the groups have similar min and max ages

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['age'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['age'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Age KDE Plot with Hue by default")
plt.legend()
plt.show()

# %% [markdown]
# Insights
#
# Orange (defaulted) group is slightly shifted to left indicating that younger folks are more likely to default on their loans

# %% [markdown]
# ### KDE for all the Columns

# %%
plt.figure(figsize=(24, 20))  # Width, height in inches

for i, col in enumerate(columns_continuous):
    plt.subplot(6, 4, i+1)  # 1 row, 4 columns, ith subplot
    sns.kdeplot(df_train_1[col][df_train_1['default']==0], fill=True, label='default=0')
    sns.kdeplot(df_train_1[col][df_train_1['default']==1], fill=True, label='default=1')
    plt.title(col)        
    plt.xlabel('')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# Insights
#
# 1. In columns: loan_tenure_months, delinquent_months, total_dpd, credit_utilization, higher values indicate high likelyhood of becoming a default. Hence these 4 looks like strong predictors
#
# 2. In remaining columns the distributions do not give any obvious insights
#
# 3. Why loan_amount and income did not give any signs of being strong predictors? May be when we combine these two and get loan to income ratio (LTI), that may have influence on the target variable. We will explore more later

# %% [markdown]
# <h3 style="color:blue" align="center">Feature Engineering, Feature Selection</h3>

# %% [markdown]
# ### Generate Loan to Income (LTI) Ratio

# %%
df_train_1[["loan_amount", "income"]].head(3)
# Out:
#        loan_amount    income
# 12746     23442000  11327000
# 32495      1149000    715000
# 43675     11296000   3195000

# %%
df_train_1['loan_to_income'] = round(df_train_1['loan_amount'] / df_train_1['income'],2)
df_train_1['loan_to_income'][1]
# Out:
# 3.22

# %%
df_train_1['loan_to_income'] = round(df_train_1['loan_amount'] / df_train_1['income'],2)
df_train_1['loan_to_income'].describe()
# Out:
# count   37488.00
# mean        1.56
# std         0.97
# min         0.30
# 25%         0.77
# 50%         1.16
# 75%         2.46
# max         4.57
# Name: loan_to_income, dtype: float64

# %%
df_test['loan_to_income'] = round(df_test['loan_amount'] / df_test['income'],2)

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['loan_to_income'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['loan_to_income'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Loan to Income Ratio (LTI) KDE Plot with Hue by default")
plt.legend()
plt.show()

# %% [markdown]
# ### Insights
#
# 1.Blue graph has majority of its values on lower side of LTI
#
# 2.Orange graph has many values when LTI is higher indicating that higher LTI means high risk loan

# %% [markdown]
# ### Generate Delinquency Ratio

# %%
df_train_1['delinquency_ratio'] = (df_train_1['delinquent_months']*100 / df_train_1['total_loan_months']).round(1)
df_test['delinquency_ratio'] = (df_test['delinquent_months']*100 / df_test['total_loan_months']).round(1)

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['delinquency_ratio'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['delinquency_ratio'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Delinquency Ratio KDE Plot with Hue by default")
plt.legend()
plt.show()

# %% [markdown]
# ### Insights
#
# 1. Blue graph has majority of its values on lower side of LTI
# 2. Orange graph has many values when delinquency ratio is higher indicating some correlation on default

# %% [markdown]
# ### Generate Avg DPD Per Delinquency

# %%
df_train_1['avg_dpd_per_delinquency'] = np.where(
    df_train_1['delinquent_months'] != 0,
    (df_train_1['total_dpd'] / df_train_1['delinquent_months']).round(1),
    0
)

df_test['avg_dpd_per_delinquency'] = np.where(
    df_test['delinquent_months'] != 0,
    (df_test['total_dpd'] / df_test['delinquent_months']).round(1),
    0
)
df_train_1['avg_dpd_per_delinquency'].describe()
# Out:
# count   37488.00
# mean        3.28
# std         2.91
# min         0.00
# 25%         0.00
# 50%         4.30
# 75%         5.72
# max        10.00
# Name: avg_dpd_per_delinquency, dtype: float64

# %%
df_train_1['avg_dpd_per_delinquency'].isna().sum()
# Out:
# 0

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['avg_dpd_per_delinquency'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['avg_dpd_per_delinquency'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Avg DPD Per Delinquency Ratio KDE Plot with Hue by default")
plt.legend()
plt.show()

# %% [markdown]
# ### Insights
#
# 1. Graph clearly shows more occurances of default cases when avg_dpd_per_delinquency is high. This means this column is a strong predictor

# %% [markdown]
# ### Feature Selection

# %% [markdown]
# ### Remove columns that are just unique ids and don't have influence on target

# %%
df_train_1.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'income', 'number_of_dependants', 'residence_type',
#        'years_at_current_address', 'city', 'state', 'zipcode', 'loan_id',
#        'loan_purpose', 'loan_type', 'sanction_amount', 'loan_amount',
#        'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months',
#        'principal_outstanding', 'bank_balance_at_application',
#        'disbursal_date', 'installment_start_dt', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
#        'total_dpd', 'enquiry_count', 'credit_utilization_ratio', 'default',
#        'loan_to_income', 'delinquency_ratio', 'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
df_train_2 = df_train_1.drop(['cust_id', 'loan_id'],axis="columns")
df_test = df_test.drop(['cust_id', 'loan_id'],axis="columns")

# %% [markdown]
# ### Remove columns that business contact person asked us to remove

# %%
df_train_3 = df_train_2.drop(['disbursal_date', 'installment_start_dt', 'loan_amount', 'income', 
                              'total_loan_months', 'delinquent_months', 'total_dpd'], axis="columns")
df_test = df_test.drop(['disbursal_date', 'installment_start_dt', 'loan_amount', 'income', 
                              'total_loan_months', 'delinquent_months', 'total_dpd'], axis="columns")
df_train_3.columns
# Out:
# Index(['age', 'gender', 'marital_status', 'employment_status',
#        'number_of_dependants', 'residence_type', 'years_at_current_address',
#        'city', 'state', 'zipcode', 'loan_purpose', 'loan_type',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'default', 'loan_to_income',
#        'delinquency_ratio', 'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
df_train_3.select_dtypes(['int64', 'float64']).columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
df_train_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37488 entries, 12746 to 37784
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          37488 non-null  int64
#  1   gender                       37488 non-null  object
#  2   marital_status               37488 non-null  object
#  3   employment_status            37488 non-null  object
#  4   number_of_dependants         37488 non-null  int64
#  5   residence_type               37488 non-null  object
#  6   years_at_current_address     37488 non-null  int64
#  7   city                         37488 non-null  object
#  8   state                        37488 non-null  object
#  9   zipcode                      37488 non-null  int64
#  10  loan_purpose                 37488 non-null  object
#  11  loan_type                    37488 non-null  object
#  12  sanction_amount              37488 non-null  int64
#  13  processing_fee               37488 non-null  float64
#  14  gst                          37488 non-null  int64
#  15  net_disbursement             37488 non-null  int64
#  16  loan_tenure_months           37488 non-null  int64
#  17  principal_outstanding        37488 non-null  int64
#  18  bank_balance_at_application  37488 non-null  int64
#  19  number_of_open_accounts      37488 non-null  int64
#  20  number_of_closed_accounts    37488 non-null  int64
#  21  enquiry_count                37488 non-null  int64
#  22  credit_utilization_ratio     37488 non-null  int64
#  23  default                      37488 non-null  int32
#  24  loan_to_income               37488 non-null  float64
#  25  delinquency_ratio            37488 non-null  float64
#  26  avg_dpd_per_delinquency      37488 non-null  float64
# dtypes: float64(4), int32(1), int64(14), object(8)
# memory usage: 8.9+ MB

# %% [markdown]
# ### VIF to measure multicolinearity

# %%
X_train = df_train_3.drop('default', axis='columns')
y_train = df_train_3['default']

from sklearn.preprocessing import MinMaxScaler

cols_to_scale = X_train.select_dtypes(['int64', 'float64']).columns

scaler = MinMaxScaler()

X_train[cols_to_scale] = scaler.fit_transform(X_train[cols_to_scale])
X_train.describe()
# Out:
#            age  number_of_dependants  years_at_current_address  zipcode  \
# count 37488.00              37488.00                  37488.00 37488.00
# mean      0.41                  0.39                      0.50     0.52
# std       0.19                  0.31                      0.30     0.29
# min       0.00                  0.00                      0.00     0.00
# 25%       0.29                  0.00                      0.23     0.33
# 50%       0.40                  0.40                      0.50     0.49
# 75%       0.54                  0.60                      0.77     0.76
# max       1.00                  1.00                      1.00     1.00
#
#        sanction_amount  processing_fee      gst  net_disbursement  \
# count         37488.00        37488.00 37488.00          37488.00
# mean              0.09            0.08     0.08              0.08
# std               0.12            0.11     0.11              0.11
# min               0.00            0.00     0.00              0.00
# 25%               0.02            0.02     0.02              0.02
# 50%               0.05            0.05     0.05              0.05
# 75%               0.10            0.10     0.10              0.10
# max               1.00            1.00     1.00              1.00
#
#        loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# count            37488.00               37488.00                     37488.00
# mean                 0.38                   0.26                         0.12
# std                  0.23                   0.24                         0.13
# min                  0.00                   0.00                         0.00
# 25%                  0.19                   0.08                         0.03
# 50%                  0.34                   0.19                         0.08
# 75%                  0.55                   0.35                         0.16
# max                  1.00                   1.00                         1.00
#
#        number_of_open_accounts  number_of_closed_accounts  enquiry_count  \
# count                 37488.00                   37488.00       37488.00
# mean                      0.50                       0.50           0.50
# std                       0.37                       0.41           0.25
# min                       0.00                       0.00           0.00
# 25%                       0.00                       0.00           0.38
# 50%                       0.67                       0.50           0.50
# 75%                       1.00                       1.00           0.62
# max                       1.00                       1.00           1.00
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# count                  37488.00        37488.00           37488.00
# mean                       0.44            0.29               0.10
# std                        0.30            0.23               0.17
# min                        0.00            0.00               0.00
# 25%                        0.18            0.11               0.00
# 50%                        0.39            0.20               0.04
# 75%                        0.68            0.51               0.13
# max                        1.00            1.00               1.00
#
#        avg_dpd_per_delinquency
# count                 37488.00
# mean                      0.33
# std                       0.29
# min                       0.00
# 25%                       0.00
# 50%                       0.43
# 75%                       0.57
# max                       1.00

# %% [markdown]
# ### Same transformation on test set

# %%
X_test = df_test.drop('default', axis='columns')
y_test = df_test['default']

X_test[cols_to_scale] = scaler.transform(X_test[cols_to_scale])
X_test.describe()
# Out:
#            age  number_of_dependants  years_at_current_address  zipcode  \
# count 12497.00              12497.00                  12497.00 12497.00
# mean      0.42                  0.38                      0.50     0.53
# std       0.19                  0.31                      0.30     0.29
# min       0.00                  0.00                      0.00     0.00
# 25%       0.29                  0.00                      0.23     0.33
# 50%       0.42                  0.40                      0.50     0.51
# 75%       0.54                  0.60                      0.77     0.76
# max       1.00                  1.00                      1.00     1.00
#
#        sanction_amount  processing_fee      gst  net_disbursement  \
# count         12497.00        12497.00 12497.00          12497.00
# mean              0.09            0.08     0.08              0.08
# std               0.12            0.11     0.11              0.11
# min              -0.00           -0.00    -0.00             -0.00
# 25%               0.02            0.02     0.02              0.02
# 50%               0.05            0.05     0.05              0.05
# 75%               0.10            0.09     0.09              0.09
# max               0.98            0.96     0.96              0.96
#
#        loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# count            12497.00               12497.00                     12497.00
# mean                 0.38                   0.26                         0.12
# std                  0.23                   0.25                         0.13
# min                  0.00                   0.00                         0.00
# 25%                  0.19                   0.08                         0.03
# 50%                  0.34                   0.20                         0.08
# 75%                  0.55                   0.36                         0.16
# max                  1.00                   1.00                         0.94
#
#        number_of_open_accounts  number_of_closed_accounts  enquiry_count  \
# count                 12497.00                   12497.00       12497.00
# mean                      0.50                       0.50           0.50
# std                       0.37                       0.41           0.25
# min                       0.00                       0.00           0.00
# 25%                       0.00                       0.00           0.38
# 50%                       0.33                       0.50           0.50
# 75%                       0.67                       1.00           0.62
# max                       1.00                       1.00           1.00
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# count                  12497.00        12497.00           12497.00
# mean                       0.44            0.29               0.11
# std                        0.30            0.23               0.17
# min                        0.00            0.00               0.00
# 25%                        0.18            0.11               0.00
# 50%                        0.39            0.20               0.04
# 75%                        0.68            0.50               0.13
# max                        1.00            1.00               1.00
#
#        avg_dpd_per_delinquency
# count                 12497.00
# mean                      0.33
# std                       0.29
# min                       0.00
# 25%                       0.00
# 50%                       0.44
# 75%                       0.58
# max                       1.00

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(data):
    vif_df = pd.DataFrame()
    vif_df['Column'] = data.columns
    vif_df['VIF'] = [variance_inflation_factor(data.values,i) for i in range(data.shape[1])]
    return vif_df

# %%
X_train.head(2)
# Out:
#        age gender marital_status employment_status  number_of_dependants  \
# 12746 0.79      M        Married     Self-Employed                  0.60
# 32495 0.50      F         Single          Salaried                  0.00
#
#       residence_type  years_at_current_address       city        state  \
# 12746          Owned                      0.97  Hyderabad    Telangana
# 32495          Owned                      0.87     Mumbai  Maharashtra
#
#        zipcode  ... loan_tenure_months principal_outstanding  \
# 12746     0.66  ...               0.42                  1.00
# 32495     0.49  ...               0.83                  0.09
#
#        bank_balance_at_application  number_of_open_accounts  \
# 12746                         0.61                     1.00
# 32495                         0.03                     0.67
#
#        number_of_closed_accounts  enquiry_count  credit_utilization_ratio  \
# 12746                       1.00           0.38                      0.36
# 32495                       0.50           0.50                      0.05
#
#        loan_to_income  delinquency_ratio  avg_dpd_per_delinquency
# 12746            0.41               0.13                     0.59
# 32495            0.31               0.06                     0.62
#
# [2 rows x 26 columns]

# %%
calculate_vif(X_train[cols_to_scale])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:195: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#                          Column    VIF
# 0                           age   5.70
# 1          number_of_dependants   2.73
# 2      years_at_current_address   3.42
# 3                       zipcode   3.80
# 4               sanction_amount 101.09
# 5                processing_fee    inf
# 6                           gst    inf
# 7              net_disbursement    inf
# 8            loan_tenure_months   6.18
# 9         principal_outstanding  16.33
# 10  bank_balance_at_application   9.34
# 11      number_of_open_accounts   4.39
# 12    number_of_closed_accounts   2.38
# 13                enquiry_count   6.41
# 14     credit_utilization_ratio   2.93
# 15               loan_to_income   6.96
# 16            delinquency_ratio   1.93
# 17      avg_dpd_per_delinquency   2.91

# %%
features_to_drop_vif = ['sanction_amount', 'processing_fee', 'gst', 'net_disbursement','principal_outstanding']


X_train_1 = X_train.drop(features_to_drop_vif, axis='columns')
numeric_columns = X_train_1.select_dtypes(['int64', 'float64']).columns
numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'loan_tenure_months', 'bank_balance_at_application',
#        'number_of_open_accounts', 'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
vif_df= calculate_vif(X_train_1[numeric_columns])
vif_df
# Out:
#                          Column  VIF
# 0                           age 5.43
# 1          number_of_dependants 2.73
# 2      years_at_current_address 3.40
# 3                       zipcode 3.78
# 4            loan_tenure_months 6.02
# 5   bank_balance_at_application 1.80
# 6       number_of_open_accounts 4.35
# 7     number_of_closed_accounts 2.37
# 8                 enquiry_count 6.38
# 9      credit_utilization_ratio 2.92
# 10               loan_to_income 4.56
# 11            delinquency_ratio 1.93
# 12      avg_dpd_per_delinquency 2.91

# %%
selected_numeric_features_vif = vif_df.Column.values
selected_numeric_features_vif
# Out:
# array(['age', 'number_of_dependants', 'years_at_current_address',
#        'zipcode', 'loan_tenure_months', 'bank_balance_at_application',
#        'number_of_open_accounts', 'number_of_closed_accounts',
#        'enquiry_count', 'credit_utilization_ratio', 'loan_to_income',
#        'delinquency_ratio', 'avg_dpd_per_delinquency'], dtype=object)

# %%
plt.figure(figsize=(12,12))
cm = df_train_3[numeric_columns.append(pd.Index(['default']))].corr()
sns.heatmap(cm, annot=True, fmt='0.2f')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Feature Selection: Categorical Feature

# %%
X_train_1.head()
# Out:
#        age gender marital_status employment_status  number_of_dependants  \
# 12746 0.79      M        Married     Self-Employed                  0.60
# 32495 0.50      F         Single          Salaried                  0.00
# 43675 0.38      M         Single          Salaried                  0.00
# 9040  0.46      M        Married          Salaried                  0.40
# 13077 0.77      M        Married     Self-Employed                  0.80
#
#       residence_type  years_at_current_address       city        state  \
# 12746          Owned                      0.97  Hyderabad    Telangana
# 32495          Owned                      0.87     Mumbai  Maharashtra
# 43675       Mortgage                      0.83    Chennai   Tamil Nadu
# 9040        Mortgage                      0.97  Bangalore    Karnataka
# 13077          Owned                      0.93       Pune  Maharashtra
#
#        zipcode  ...  loan_type loan_tenure_months  \
# 12746     0.66  ...    Secured               0.42
# 32495     0.49  ...    Secured               0.83
# 43675     0.83  ...    Secured               0.49
# 9040      0.76  ...    Secured               0.64
# 13077     0.51  ...  Unsecured               0.17
#
#        bank_balance_at_application  number_of_open_accounts  \
# 12746                         0.61                     1.00
# 32495                         0.03                     0.67
# 43675                         0.17                     0.00
# 9040                          0.08                     0.67
# 13077                         0.07                     0.00
#
#        number_of_closed_accounts  enquiry_count  credit_utilization_ratio  \
# 12746                       1.00           0.38                      0.36
# 32495                       0.50           0.50                      0.05
# 43675                       0.50           0.38                      0.00
# 9040                        0.00           0.88                      0.88
# 13077                       1.00           0.00                      0.72
#
#        loan_to_income  delinquency_ratio  avg_dpd_per_delinquency
# 12746            0.41               0.13                     0.59
# 32495            0.31               0.06                     0.62
# 43675            0.76               0.22                     0.56
# 9040             0.19               0.00                     0.00
# 13077            0.05               0.00                     0.00
#
# [5 rows x 21 columns]

# %%
columns_categorical
# Out:
# ['gender',
#  'marital_status',
#  'employment_status',
#  'residence_type',
#  'city',
#  'state',
#  'zipcode',
#  'loan_purpose',
#  'loan_type',
#  'default']

# %%
temp= pd.concat([X_train_1, y_train], axis=1)
temp.groupby('loan_purpose')['default'].agg(['count','sum'])
# Out:
#               count   sum
# loan_purpose
# Auto           7447   327
# Education      5620   559
# Home          11304  1734
# Personal      13117   603

# %% [markdown]
# ### Calculate WOE and IV

# %%
def calculate_woe_iv(df, feature, target):
    grouped = df.groupby(feature)[target].agg(['count','sum'])
    grouped = grouped.rename(columns={'count': 'total', 'sum': 'good'})
    grouped['bad']=grouped['total']-grouped['good']
    
    total_good = grouped['good'].sum()
    total_bad = grouped['bad'].sum()
    
    grouped['good_pct'] = grouped['good'] / total_good
    grouped['bad_pct'] = grouped['bad'] / total_bad
    grouped['woe'] = np.log(grouped['good_pct']/ grouped['bad_pct'])
    grouped['iv'] = (grouped['good_pct'] -grouped['bad_pct'])*grouped['woe']
    
    grouped['woe'] = grouped['woe'].replace([np.inf, -np.inf], 0)
    grouped['iv'] = grouped['iv'].replace([np.inf, -np.inf], 0)
    
    total_iv = grouped['iv'].sum()
    
    return grouped, total_iv

grouped, total_iv = calculate_woe_iv(pd.concat([X_train_1, y_train],axis=1), 'loan_purpose', 'default')
grouped
# Out:
#               total  good    bad  good_pct  bad_pct   woe   iv
# loan_purpose
# Auto           7447   327   7120      0.10     0.21 -0.72 0.08
# Education      5620   559   5061      0.17     0.15  0.16 0.00
# Home          11304  1734   9570      0.54     0.28  0.66 0.17
# Personal      13117   603  12514      0.19     0.37 -0.67 0.12

# %%
X_train_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37488 entries, 12746 to 37784
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          37488 non-null  float64
#  1   gender                       37488 non-null  object
#  2   marital_status               37488 non-null  object
#  3   employment_status            37488 non-null  object
#  4   number_of_dependants         37488 non-null  float64
#  5   residence_type               37488 non-null  object
#  6   years_at_current_address     37488 non-null  float64
#  7   city                         37488 non-null  object
#  8   state                        37488 non-null  object
#  9   zipcode                      37488 non-null  float64
#  10  loan_purpose                 37488 non-null  object
#  11  loan_type                    37488 non-null  object
#  12  loan_tenure_months           37488 non-null  float64
#  13  bank_balance_at_application  37488 non-null  float64
#  14  number_of_open_accounts      37488 non-null  float64
#  15  number_of_closed_accounts    37488 non-null  float64
#  16  enquiry_count                37488 non-null  float64
#  17  credit_utilization_ratio     37488 non-null  float64
#  18  loan_to_income               37488 non-null  float64
#  19  delinquency_ratio            37488 non-null  float64
#  20  avg_dpd_per_delinquency      37488 non-null  float64
# dtypes: float64(13), object(8)
# memory usage: 7.3+ MB

# %%
iv_values = {}

for feature in X_train_1.columns:
    if X_train_1[feature].dtype == 'object':
        _, iv = calculate_woe_iv(pd.concat([X_train_1, y_train],axis=1), feature, 'default' )
    else:
        X_binned = pd.cut(X_train_1[feature], bins=10, labels=False)
        _, iv = calculate_woe_iv(pd.concat([X_binned, y_train],axis=1), feature, 'default' )
    iv_values[feature] = iv
        
iv_values
# Out:
# {'age': 0.0890689462679479,
#  'gender': 0.00047449502170914947,
#  'marital_status': 0.001129766845390142,
#  'employment_status': 0.003953046301722585,
#  'number_of_dependants': 0.0019380899135053508,
#  'residence_type': 0.246745268718145,
#  'years_at_current_address': 0.0020800513608156363,
#  'city': 0.0019059578709781529,
#  'state': 0.0019005589806779287,
#  'zipcode': 0.0016677413243392572,
#  'loan_purpose': 0.3691197842282755,
#  'loan_type': 0.16319324904149224,
#  'loan_tenure_months': 0.21893515090196278,
#  'bank_balance_at_application': 0.0063187993277516365,
#  'number_of_open_accounts': 0.08463134083005877,
#  'number_of_closed_accounts': 0.0011964272592421567,
#  'enquiry_count': 0.007864214085342608,
#  'credit_utilization_ratio': 2.352965568168245,
#  'loan_to_income': 0.476415456948364,
#  'delinquency_ratio': 0.716576108689321,
#  'avg_dpd_per_delinquency': 0.40151905412190175}

# %%
pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x))

iv_df = pd.DataFrame(list(iv_values.items()), columns=['Feature', 'IV'])
iv_df = iv_df.sort_values(by='IV', ascending=False)
iv_df
# Out:
#                         Feature    IV
# 17     credit_utilization_ratio 2.353
# 19            delinquency_ratio 0.717
# 18               loan_to_income 0.476
# 20      avg_dpd_per_delinquency 0.402
# 10                 loan_purpose 0.369
# 5                residence_type 0.247
# 12           loan_tenure_months 0.219
# 11                    loan_type 0.163
# 0                           age 0.089
# 14      number_of_open_accounts 0.085
# 16                enquiry_count 0.008
# 13  bank_balance_at_application 0.006
# 3             employment_status 0.004
# 6      years_at_current_address 0.002
# 4          number_of_dependants 0.002
# 7                          city 0.002
# 8                         state 0.002
# 9                       zipcode 0.002
# 15    number_of_closed_accounts 0.001
# 2                marital_status 0.001
# 1                        gender 0.000

# %%
# select features that has IV > 0.02
selected_features_iv = [feature for feature, iv in iv_values.items() if iv > 0.02]
selected_features_iv
# Out:
# ['age',
#  'residence_type',
#  'loan_purpose',
#  'loan_type',
#  'loan_tenure_months',
#  'number_of_open_accounts',
#  'credit_utilization_ratio',
#  'loan_to_income',
#  'delinquency_ratio',
#  'avg_dpd_per_delinquency']

# %% [markdown]
# ### Feature Encoding

# %%
X_train_reduced = X_train_1[selected_features_iv]
X_test_reduced = X_test[selected_features_iv]

# %%
X_train_encoded = pd.get_dummies(X_train_reduced, drop_first=True)
X_train_encoded.head(3)
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 12746 0.788               0.415                    1.000
# 32495 0.500               0.830                    0.667
# 43675 0.385               0.491                    0.000
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 12746                     0.364           0.415              0.132
# 32495                     0.051           0.307              0.062
# 43675                     0.000           0.759              0.222
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 12746                    0.590                     1                      0
# 32495                    0.620                     1                      0
# 43675                    0.560                     0                      0
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 12746                       0                  1                      0
# 32495                       1                  0                      0
# 43675                       0                  1                      0
#
#        loan_type_Unsecured
# 12746                    0
# 32495                    0
# 43675                    0

# %%
X_test_encoded = pd.get_dummies(X_test_reduced, drop_first=True)
X_test_encoded.head(3)
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 19205 0.346               0.755                    0.333
# 15514 0.481               0.226                    1.000
# 30367 0.231               0.547                    0.667
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 19205                     0.990           0.550              0.000
# 15514                     0.323           0.220              0.000
# 30367                     0.828           0.180              0.000
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 19205                    0.000                     1                      0
# 15514                    0.000                     1                      0
# 30367                    0.000                     1                      0
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 19205                       0                  1                      0
# 15514                       1                  0                      0
# 30367                       0                  0                      0
#
#        loan_type_Unsecured
# 19205                    0
# 15514                    0
# 30367                    0

# %%
X_test_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12497 entries, 19205 to 26116
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       12497 non-null  float64
#  1   loan_tenure_months        12497 non-null  float64
#  2   number_of_open_accounts   12497 non-null  float64
#  3   credit_utilization_ratio  12497 non-null  float64
#  4   loan_to_income            12497 non-null  float64
#  5   delinquency_ratio         12497 non-null  float64
#  6   avg_dpd_per_delinquency   12497 non-null  float64
#  7   residence_type_Owned      12497 non-null  uint8
#  8   residence_type_Rented     12497 non-null  uint8
#  9   loan_purpose_Education    12497 non-null  uint8
#  10  loan_purpose_Home         12497 non-null  uint8
#  11  loan_purpose_Personal     12497 non-null  uint8
#  12  loan_type_Unsecured       12497 non-null  uint8
# dtypes: float64(7), uint8(6)
# memory usage: 854.3 KB

# %% [markdown]
# <h3 align="center" style="color:blue">Model Training</h3>

# %% [markdown]
# ### Attempt 1
# 1.Logistic Regression, RandomForest & XGB
#
# 2.No handling of class imbalance

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

model = LogisticRegression()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11423
#            1       0.84      0.72      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.91      0.85      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %%
feature_importance = model.coef_[0]

# Create a DataFrame for easier handling
coef_df = pd.DataFrame(feature_importance, index=X_train_encoded.columns, columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in Logistic Regression')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11423
#            1       0.86      0.71      0.77      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.91      0.85      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %%
from xgboost import XGBClassifier

model = XGBClassifier()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     11423
#            1       0.82      0.76      0.79      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.90      0.87      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %% [markdown]
# Since there is not much difference between XGB and Logistic, we will choose LogisticRegression as a candidate for our RandomizedSearchCV candidate it has a better interpretation.

# %% [markdown]
# ### RandomizedSearch CV for Attempt 1: Logistic Regression

# %%
from sklearn.model_selection import RandomizedSearchCV

param_dist = {
    'C': np.logspace(-4, 4, 20),  # Logarithmically spaced values from 10^-4 to 10^4
    'solver': ['lbfgs', 'saga', 'liblinear', 'newton-cg']   # Algorithm to use in the optimization problem
}

# Create the Logistic Regression model
log_reg = LogisticRegression(max_iter=10000)  # Increased max_iter for convergence

# Set up RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=log_reg,
    param_distributions=param_dist,
    n_iter=50,  # Number of parameter settings that are sampled
    scoring='f1',
    cv=3,  # 5-fold cross-validation
    verbose=2,
    random_state=42,  # Set a random state for reproducibility
    n_jobs=-1  # Use all available cores
)

# Fit the RandomizedSearchCV to the training data
random_search.fit(X_train_encoded, y_train)

# Print the best parameters and best score
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")

best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test_encoded)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# Best Parameters: {'solver': 'liblinear', 'C': 1438.44988828766}
# Best Score: 0.7578820896729831
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     11423
#            1       0.83      0.74      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.90      0.86      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %% [markdown]
# ### RandomizedSearch CV for Attempt 1: XGBoost

# %%
from scipy.stats import uniform, randint
from sklearn.model_selection import RandomizedSearchCV

# Define parameter distribution for RandomizedSearchCV
param_dist = {
    'n_estimators': [100, 150, 200, 250, 300],
    'max_depth': [3, 4, 5, 6, 7, 8, 9, 10],
    'learning_rate': [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3],
    'subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
    'scale_pos_weight': [1, 2, 3, 5, 7, 10],
    'reg_alpha': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0],  # L1 regularization term
    'reg_lambda': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0]  # L2 regularization term
}

xgb = XGBClassifier()

random_search = RandomizedSearchCV(estimator=xgb, param_distributions=param_dist, n_iter=100,
                                   scoring='f1', cv=3, verbose=1, n_jobs=-1, random_state=42)

random_search.fit(X_train_encoded, y_train)

# Print the best parameters and best score
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")

best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test_encoded)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Best Parameters: {'subsample': 0.9, 'scale_pos_weight': 2, 'reg_lambda': 10.0, 'reg_alpha': 10.0, 'n_estimators': 300, 'max_depth': 10, 'learning_rate': 0.2, 'colsample_bytree': 0.6}
# Best Score: 0.7897950086476456
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     11423
#            1       0.78      0.82      0.80      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.88      0.90      0.89     12497
# weighted avg       0.97      0.96      0.96     12497

# %% [markdown]
# ### Attempt 2
# 1. Logistic Regression & XGB
# 2. Handle Class Imbalance Using Under Sampling

# %%
pip install imbalanced-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: imbalanced-learn in c:\users\debas\appdata\roaming\python\python39\site-packages (0.12.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\debas\appdata\roaming\python\python39\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\debas\appdata\roaming\python\python39\site-packages (from imbalanced-learn) (1.24.4)
# Requirement already satisfied: scipy>=1.5.0 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn) (1.9.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
y_train.value_counts()
# Out:
# 0    34265
# 1     3223
# Name: default, dtype: int64

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=42)
X_train_res, y_train_res = rus.fit_resample(X_train_encoded, y_train)
y_train_res.value_counts()
# Out:
# 0    3223
# 1    3223
# Name: default, dtype: int64

# %%
model = LogisticRegression()
model.fit(X_train_res, y_train_res)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95     11423
#            1       0.51      0.96      0.67      1074
#
#     accuracy                           0.92     12497
#    macro avg       0.75      0.93      0.81     12497
# weighted avg       0.95      0.92      0.93     12497

# %%
model = XGBClassifier(**random_search.best_params_)
model.fit(X_train_res, y_train_res)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95     11423
#            1       0.52      0.99      0.68      1074
#
#     accuracy                           0.92     12497
#    macro avg       0.76      0.95      0.82     12497
# weighted avg       0.96      0.92      0.93     12497

# %% [markdown]
# ### Attempt 3
#
# 1. Logistic Regression
#
# 2. Handle Class Imbalance Using SMOTE Tomek
#
# 3. Parameter tunning using optuna

# %%
# from imblearn.combine import 0.9
from imblearn.combine import SMOTETomek

smt = SMOTETomek(random_state=42)
X_train_smt, y_train_smt = smt.fit_resample(X_train_encoded, y_train)
y_train_smt.value_counts()
# Out:
# 0    34195
# 1    34195
# Name: default, dtype: int64

# %%
model = LogisticRegression()
model.fit(X_train_smt, y_train_smt)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.55      0.94      0.70      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.77      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %%
from xgboost import XGBClassifier

model = XGBClassifier()
model.fit(X_train_smt, y_train_smt)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98     11423
#            1       0.74      0.83      0.79      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.86      0.90      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %%
model = RandomForestClassifier()
model.fit(X_train_smt, y_train_smt)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98     11423
#            1       0.71      0.87      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.85      0.92      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %%
! pip install optuna
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: optuna in c:\users\debas\appdata\roaming\python\python39\site-packages (3.6.1)
# Requirement already satisfied: PyYAML in c:\programdata\anaconda3\lib\site-packages (from optuna) (6.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\debas\appdata\roaming\python\python39\site-packages (from optuna) (1.13.2)
# Requirement already satisfied: numpy in c:\users\debas\appdata\roaming\python\python39\site-packages (from optuna) (1.24.4)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from optuna) (4.64.1)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from optuna) (21.3)
# Requirement already satisfied: colorlog in c:\users\debas\appdata\roaming\python\python39\site-packages (from optuna) (6.8.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in c:\programdata\anaconda3\lib\site-packages (from optuna) (1.4.39)
# Requirement already satisfied: Mako in c:\users\debas\appdata\roaming\python\python39\site-packages (from alembic>=1.5.0->optuna) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in c:\programdata\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (4.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=20.0->optuna) (3.0.9)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from sqlalchemy>=1.3.0->optuna) (1.1.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from colorlog->optuna) (0.4.5)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\programdata\anaconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.0.1)

# %%
import optuna
from sklearn.metrics import make_scorer, f1_score
from sklearn.model_selection import cross_val_score

# %%
# Define the objective function for Optuna
def objective(trial):
    param = {
        'C': trial.suggest_float('C', 1e-4, 1e4, log=True),  # Logarithmically spaced values
        'solver': trial.suggest_categorical('solver', ['lbfgs', 'liblinear', 'saga', 'newton-cg']),  # Solvers
        'tol': trial.suggest_float('tol', 1e-6, 1e-1, log=True),  # Logarithmically spaced values for tolerance
        'class_weight': trial.suggest_categorical('class_weight', [None, 'balanced'])  # Class weights
    }

    model = LogisticRegression(**param, max_iter=10000)
    
    # Calculate the cross-validated f1_score
    f1_scorer = make_scorer(f1_score, average='macro')
    scores = cross_val_score(model, X_train_smt, y_train_smt, cv=3, scoring=f1_scorer, n_jobs=1)
    
    return np.mean(scores)

study_logistic = optuna.create_study(direction='maximize')
study_logistic.optimize(objective, n_trials=50)
# Out:
# [I 2024-08-22 19:09:28,767] A new study created in memory with name: no-name-c3b5de52-f37a-4f44-adb2-6d952229c485
# [I 2024-08-22 19:09:29,149] Trial 0 finished with value: 0.9394299879330691 and parameters: {'C': 0.10257515146475617, 'solver': 'liblinear', 'tol': 0.00010887895402527868, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.9394299879330691.
# [I 2024-08-22 19:09:29,480] Trial 1 finished with value: 0.94485028425619 and parameters: {'C': 0.7371413757276553, 'solver': 'liblinear', 'tol': 0.007349229832618092, 'class_weight': None}. Best is trial 1 with value: 0.94485028425619.
# [I 2024-08-22 19:09:29,649] Trial 2 finished with value: 0.9457462153700277 and parameters: {'C': 15.073415923985284, 'solver': 'saga', 'tol': 0.06967784254604638, 'class_weight': None}. Best is trial 2 with value: 0.9457462153700277.
# [I 2024-08-22 19:09:30,599] Trial 3 finished with value: 0.9456794085990863 and parameters: {'C': 1645.0401329758135, 'solver': 'newton-cg', 'tol': 4.2300522266233954e-05, 'class_weight': None}. Best is trial 2 with value: 0.9457462153700277.
# [I 2024-08-22 19:09:31,151] Trial 4 finished with value: 0.9458096260855683 and parameters: {'C': 3.1656067558794874, 'solver': 'lbfgs', 'tol': 0.029233391342451266, 'class_weight': None}. Best is trial 4 with value: 0.9458096260855683.
# [I 2024-08-22 19:09:31,751] Trial 5 finished with value: 0.9457935410854216 and parameters: {'C': 1.7959404052924015, 'solver': 'lbfgs', 'tol': 0.00016169249044041588, 'class_weight': 'balanced'}. Best is trial 4 with value: 0.9458096260855683.
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\_linesearch.py:305: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\optimize.py:203: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# [I 2024-08-22 19:09:32,685] Trial 6 finished with value: 0.8741211398474428 and parameters: {'C': 0.0004237962735441302, 'solver': 'newton-cg', 'tol': 1.3356343179519779e-05, 'class_weight': 'balanced'}. Best is trial 4 with value: 0.9458096260855683.
# [I 2024-08-22 19:09:33,280] Trial 7 finished with value: 0.9456940531683539 and parameters: {'C': 9866.273520885332, 'solver': 'lbfgs', 'tol': 0.0014919449723903616, 'class_weight': 'balanced'}. Best is trial 4 with value: 0.9458096260855683.
# [I 2024-08-22 19:09:33,659] Trial 8 finished with value: 0.9283463028006992 and parameters: {'C': 0.008443240307760464, 'solver': 'lbfgs', 'tol': 0.00040763575430214104, 'class_weight': 'balanced'}. Best is trial 4 with value: 0.9458096260855683.
# [I 2024-08-22 19:09:33,807] Trial 9 finished with value: 0.9455046682134376 and parameters: {'C': 2075.963993076833, 'solver': 'saga', 'tol': 0.0534625511015041, 'class_weight': None}. Best is trial 4 with value: 0.9458096260855683.
# [I 2024-08-22 19:09:34,427] Trial 10 finished with value: 0.9456208359010468 and parameters: {'C': 46.739797025210116, 'solver': 'lbfgs', 'tol': 0.00382432925811847, 'class_weight': None}. Best is trial 4 with value: 0.9458096260855683.
# [I 2024-08-22 19:09:35,045] Trial 11 finished with value: 0.9456789875532214 and parameters: {'C': 11.985275542615174, 'solver': 'lbfgs', 'tol': 3.413357220975828e-06, 'class_weight': 'balanced'}. Best is trial 4 with value: 0.9458096260855683.
# [I 2024-08-22 19:09:35,550] Trial 12 finished with value: 0.9428271717972007 and parameters: {'C': 0.17701634624882281, 'solver': 'lbfgs', 'tol': 0.000475631459482651, 'class_weight': None}. Best is trial 4 with value: 0.9458096260855683.
# [I 2024-08-22 19:09:36,113] Trial 13 finished with value: 0.9456354945573398 and parameters: {'C': 95.22523452416985, 'solver': 'lbfgs', 'tol': 0.012426441504944055, 'class_weight': 'balanced'}. Best is trial 4 with value: 0.9458096260855683.
# [I 2024-08-22 19:09:36,485] Trial 14 finished with value: 0.9303149211469949 and parameters: {'C': 0.010504384798268832, 'solver': 'lbfgs', 'tol': 6.55143641393937e-05, 'class_weight': None}. Best is trial 4 with value: 0.9458096260855683.
# [I 2024-08-22 19:09:37,111] Trial 15 finished with value: 0.9458378636399077 and parameters: {'C': 2.148245317742643, 'solver': 'lbfgs', 'tol': 2.1389836932712066e-06, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\_linesearch.py:305: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\optimize.py:203: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# [I 2024-08-22 19:09:38,290] Trial 16 finished with value: 0.945779739270774 and parameters: {'C': 2.439884943566922, 'solver': 'newton-cg', 'tol': 2.139373075314787e-06, 'class_weight': None}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:39,146] Trial 17 finished with value: 0.9456648044554358 and parameters: {'C': 327.3272431594792, 'solver': 'saga', 'tol': 1.0359363259221604e-06, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:39,464] Trial 18 finished with value: 0.9284297898745608 and parameters: {'C': 0.020898561062505004, 'solver': 'liblinear', 'tol': 8.752437560856475e-06, 'class_weight': None}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:39,670] Trial 19 finished with value: 0.8229912997060692 and parameters: {'C': 0.00011638396044730368, 'solver': 'lbfgs', 'tol': 0.0014089339114976569, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:40,193] Trial 20 finished with value: 0.9431945109312542 and parameters: {'C': 0.21019694608031184, 'solver': 'lbfgs', 'tol': 0.028697876427856612, 'class_weight': None}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:40,748] Trial 21 finished with value: 0.9457938526872226 and parameters: {'C': 2.0521865582460146, 'solver': 'lbfgs', 'tol': 2.8124958431159704e-05, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:41,346] Trial 22 finished with value: 0.9457227175420296 and parameters: {'C': 8.228873962189757, 'solver': 'lbfgs', 'tol': 1.5193091376495712e-05, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:41,929] Trial 23 finished with value: 0.945469786761597 and parameters: {'C': 0.7840065372185367, 'solver': 'lbfgs', 'tol': 4.80191019761363e-06, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:42,498] Trial 24 finished with value: 0.9456062390565747 and parameters: {'C': 75.71834077729419, 'solver': 'lbfgs', 'tol': 4.339430672931337e-05, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:43,065] Trial 25 finished with value: 0.9458245878376202 and parameters: {'C': 4.058421001554673, 'solver': 'lbfgs', 'tol': 1.2508918490881966e-06, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:43,457] Trial 26 finished with value: 0.9385620642176465 and parameters: {'C': 0.08660504364614059, 'solver': 'liblinear', 'tol': 2.0098635911255398e-06, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:44,140] Trial 27 finished with value: 0.945751910522051 and parameters: {'C': 6.8360726080137075, 'solver': 'saga', 'tol': 6.6580075525919785e-06, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:45,028] Trial 28 finished with value: 0.9450145439522549 and parameters: {'C': 0.4862412678986981, 'solver': 'newton-cg', 'tol': 1.3110210100813088e-06, 'class_weight': None}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:45,304] Trial 29 finished with value: 0.9341674878255599 and parameters: {'C': 0.043025932516027175, 'solver': 'liblinear', 'tol': 0.0009730311230797961, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:45,909] Trial 30 finished with value: 0.9456647572372227 and parameters: {'C': 230.7513045531145, 'solver': 'lbfgs', 'tol': 0.00017704286941369986, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:46,497] Trial 31 finished with value: 0.945794970023543 and parameters: {'C': 3.2869908027082286, 'solver': 'lbfgs', 'tol': 2.349395683485682e-05, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:47,063] Trial 32 finished with value: 0.9455915325213132 and parameters: {'C': 30.006757683892808, 'solver': 'lbfgs', 'tol': 2.9828445976906566e-06, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:47,630] Trial 33 finished with value: 0.9457663011570284 and parameters: {'C': 5.592001914230971, 'solver': 'lbfgs', 'tol': 1.9803247069734456e-05, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:48,260] Trial 34 finished with value: 0.9452939540863593 and parameters: {'C': 0.6621514815198013, 'solver': 'lbfgs', 'tol': 5.166826513230684e-06, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:48,712] Trial 35 finished with value: 0.9456612188046164 and parameters: {'C': 2.2772797895497563, 'solver': 'liblinear', 'tol': 9.627334074420257e-05, 'class_weight': None}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:49,298] Trial 36 finished with value: 0.9456061292723144 and parameters: {'C': 27.9411063191082, 'solver': 'lbfgs', 'tol': 1.1080764800101494e-06, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:50,022] Trial 37 finished with value: 0.9443395649941806 and parameters: {'C': 0.33740783202963065, 'solver': 'newton-cg', 'tol': 0.00568094170241969, 'class_weight': None}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:50,769] Trial 38 finished with value: 0.9457804778605787 and parameters: {'C': 3.4733250193548453, 'solver': 'saga', 'tol': 8.192013135820479e-06, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:51,063] Trial 39 finished with value: 0.921393481441628 and parameters: {'C': 0.0037611411153358073, 'solver': 'lbfgs', 'tol': 3.139239951970678e-05, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:51,708] Trial 40 finished with value: 0.9456648044554358 and parameters: {'C': 249.04024428765456, 'solver': 'lbfgs', 'tol': 0.015055202858388841, 'class_weight': None}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:52,233] Trial 41 finished with value: 0.9456318679813585 and parameters: {'C': 1.1867701093471223, 'solver': 'lbfgs', 'tol': 0.09743806670496566, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:52,831] Trial 42 finished with value: 0.9456497363170232 and parameters: {'C': 13.064679256887, 'solver': 'lbfgs', 'tol': 2.348576198911603e-05, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:53,422] Trial 43 finished with value: 0.9457641917006621 and parameters: {'C': 1.6414017307441549, 'solver': 'lbfgs', 'tol': 0.00022567483441490136, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:54,045] Trial 44 finished with value: 0.9456205669656254 and parameters: {'C': 19.093507074760453, 'solver': 'lbfgs', 'tol': 1.1652939574749493e-05, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:54,525] Trial 45 finished with value: 0.9412115622196288 and parameters: {'C': 0.10561368999970748, 'solver': 'lbfgs', 'tol': 8.190889979273379e-05, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:55,505] Trial 46 finished with value: 0.9457658743737323 and parameters: {'C': 3.5134845424219705, 'solver': 'newton-cg', 'tol': 2.302970626131313e-06, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:56,054] Trial 47 finished with value: 0.9455878822139773 and parameters: {'C': 1.0983378329992743, 'solver': 'lbfgs', 'tol': 0.003602028434820293, 'class_weight': None}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:56,521] Trial 48 finished with value: 0.9457953994570842 and parameters: {'C': 4.541486283969127, 'solver': 'saga', 'tol': 0.0007740851208581623, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.
# [I 2024-08-22 19:09:56,940] Trial 49 finished with value: 0.9456356972913688 and parameters: {'C': 52.09075535717173, 'solver': 'saga', 'tol': 0.0006383535273969899, 'class_weight': 'balanced'}. Best is trial 15 with value: 0.9458378636399077.

# %%
print('Best trial:')
trial = study_logistic.best_trial
print('  F1-score: {}'.format(trial.value))
print('  Params: ')
for key, value in trial.params.items():
    print('    {}: {}'.format(key, value))
    
best_model_logistic = LogisticRegression(**study_logistic.best_params)
best_model_logistic.fit(X_train_smt, y_train_smt)

# Evaluate on the test set
y_pred = best_model_logistic.predict(X_test_encoded)

report = classification_report(y_test, y_pred)
print(report)
# Out:
# Best trial:
#   F1-score: 0.9458378636399077
#   Params:
#     C: 2.148245317742643
#     solver: lbfgs
#     tol: 2.1389836932712066e-06
#     class_weight: balanced
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.56      0.94      0.70      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.78      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %% [markdown]
# ### Attempt 4
#
# 1. XGBoost
# 2. Handle Class Imbalance Using SMOTE Tomek
# 3. Parameter tunning using optuna

# %%
# Define the objective function for Optuna
def objective(trial):
    param = {
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'verbosity': 0,
        'booster': 'gbtree',
        'lambda': trial.suggest_float('lambda', 1e-3, 10.0, log=True),
        'alpha': trial.suggest_float('alpha', 1e-3, 10.0, log=True),
        'subsample': trial.suggest_float('subsample', 0.4, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.4, 1.0),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'eta': trial.suggest_float('eta', 0.01, 0.3),
        'gamma': trial.suggest_float('gamma', 0, 10),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1, 10),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'max_delta_step': trial.suggest_int('max_delta_step', 0, 10)
    }

    model = XGBClassifier(**param)
    
    # Calculate the cross-validated f1_score
    f1_scorer = make_scorer(f1_score, average='macro')
    scores = cross_val_score(model, X_train_smt, y_train_smt, cv=3, scoring=f1_scorer, n_jobs=1)
    
    return np.mean(scores)

study_xgb = optuna.create_study(direction='maximize')
study_xgb.optimize(objective, n_trials=50)
# Out:
# [I 2024-08-22 19:09:57,219] A new study created in memory with name: no-name-365e4ed4-05d8-40aa-9328-57a16e82ec20
# [I 2024-08-22 19:09:57,767] Trial 0 finished with value: 0.9551596998895828 and parameters: {'lambda': 0.015714900564182253, 'alpha': 5.077985116452279, 'subsample': 0.6411729529139558, 'colsample_bytree': 0.47116193088663705, 'max_depth': 5, 'eta': 0.2170911877227081, 'gamma': 4.162588642669734, 'scale_pos_weight': 7.189860571137162, 'min_child_weight': 6, 'max_delta_step': 10}. Best is trial 0 with value: 0.9551596998895828.
# [I 2024-08-22 19:09:58,418] Trial 1 finished with value: 0.954187241735835 and parameters: {'lambda': 0.002411394904455762, 'alpha': 1.3873620505586137, 'subsample': 0.6476109715931159, 'colsample_bytree': 0.6240132472982406, 'max_depth': 6, 'eta': 0.11295396188087713, 'gamma': 4.278389410235991, 'scale_pos_weight': 7.324221360921649, 'min_child_weight': 9, 'max_delta_step': 10}. Best is trial 0 with value: 0.9551596998895828.
# [I 2024-08-22 19:09:59,062] Trial 2 finished with value: 0.9601740427911744 and parameters: {'lambda': 0.29709419683090443, 'alpha': 0.8198229432553972, 'subsample': 0.5318956953824137, 'colsample_bytree': 0.6101403743903653, 'max_depth': 6, 'eta': 0.11884314494034838, 'gamma': 1.6847311393610154, 'scale_pos_weight': 3.9542479701238324, 'min_child_weight': 1, 'max_delta_step': 10}. Best is trial 2 with value: 0.9601740427911744.
# [I 2024-08-22 19:09:59,692] Trial 3 finished with value: 0.9654290734903158 and parameters: {'lambda': 0.0558067827050278, 'alpha': 0.02852473334864183, 'subsample': 0.5682614378323954, 'colsample_bytree': 0.8788003016754204, 'max_depth': 8, 'eta': 0.19392509120263968, 'gamma': 7.059069668102237, 'scale_pos_weight': 8.500534283255725, 'min_child_weight': 1, 'max_delta_step': 8}. Best is trial 3 with value: 0.9654290734903158.
# [I 2024-08-22 19:10:00,498] Trial 4 finished with value: 0.9630645118209742 and parameters: {'lambda': 0.0026991628838022937, 'alpha': 5.070398004811379, 'subsample': 0.6860775870713158, 'colsample_bytree': 0.6104225613922598, 'max_depth': 10, 'eta': 0.15231146516545682, 'gamma': 4.977673327074132, 'scale_pos_weight': 6.748225520379873, 'min_child_weight': 2, 'max_delta_step': 3}. Best is trial 3 with value: 0.9654290734903158.
# [I 2024-08-22 19:10:01,220] Trial 5 finished with value: 0.9677369246905979 and parameters: {'lambda': 0.14250604080779475, 'alpha': 0.10174025968580526, 'subsample': 0.8559801120205006, 'colsample_bytree': 0.8264357665012312, 'max_depth': 8, 'eta': 0.09741922482021939, 'gamma': 6.302860036611401, 'scale_pos_weight': 2.306070013626747, 'min_child_weight': 8, 'max_delta_step': 8}. Best is trial 5 with value: 0.9677369246905979.
# [I 2024-08-22 19:10:01,827] Trial 6 finished with value: 0.9665293699404222 and parameters: {'lambda': 0.6105077204301147, 'alpha': 0.0033796215631502714, 'subsample': 0.8707278514378843, 'colsample_bytree': 0.9235944854299191, 'max_depth': 10, 'eta': 0.2012646815251316, 'gamma': 7.247663816585814, 'scale_pos_weight': 5.912302711393323, 'min_child_weight': 5, 'max_delta_step': 3}. Best is trial 5 with value: 0.9677369246905979.
# [I 2024-08-22 19:10:02,381] Trial 7 finished with value: 0.9670573270754024 and parameters: {'lambda': 0.03038757666852649, 'alpha': 0.01251772809499938, 'subsample': 0.8990564208995191, 'colsample_bytree': 0.8558515721312931, 'max_depth': 8, 'eta': 0.2079181353460703, 'gamma': 7.278435619759143, 'scale_pos_weight': 5.011327077422918, 'min_child_weight': 4, 'max_delta_step': 5}. Best is trial 5 with value: 0.9677369246905979.
# [I 2024-08-22 19:10:03,041] Trial 8 finished with value: 0.9688310995183617 and parameters: {'lambda': 0.03683511610632296, 'alpha': 0.6340746659975777, 'subsample': 0.8313745859375596, 'colsample_bytree': 0.750125595928839, 'max_depth': 9, 'eta': 0.20441479910869284, 'gamma': 4.404663050352847, 'scale_pos_weight': 5.250582961418926, 'min_child_weight': 9, 'max_delta_step': 4}. Best is trial 8 with value: 0.9688310995183617.
# [I 2024-08-22 19:10:03,583] Trial 9 finished with value: 0.9436052992666496 and parameters: {'lambda': 0.0023630188689369425, 'alpha': 0.33291260769009673, 'subsample': 0.6182256733710922, 'colsample_bytree': 0.6729152760017576, 'max_depth': 4, 'eta': 0.13354156239483347, 'gamma': 1.2503129126467527, 'scale_pos_weight': 8.152482037939906, 'min_child_weight': 3, 'max_delta_step': 10}. Best is trial 8 with value: 0.9688310995183617.
# [I 2024-08-22 19:10:04,180] Trial 10 finished with value: 0.959965208725515 and parameters: {'lambda': 5.528493601272242, 'alpha': 0.0014462039638784706, 'subsample': 0.4287142341325697, 'colsample_bytree': 0.9914547950607966, 'max_depth': 3, 'eta': 0.29510103202973603, 'gamma': 9.469422786705142, 'scale_pos_weight': 2.4718362694887963, 'min_child_weight': 10, 'max_delta_step': 0}. Best is trial 8 with value: 0.9688310995183617.
# [I 2024-08-22 19:10:05,245] Trial 11 finished with value: 0.9652827284644702 and parameters: {'lambda': 0.2957285841355863, 'alpha': 0.0499074031436624, 'subsample': 0.8310623154901485, 'colsample_bytree': 0.7710531362305215, 'max_depth': 8, 'eta': 0.0433485523492792, 'gamma': 2.9794542631164784, 'scale_pos_weight': 1.1647915995474927, 'min_child_weight': 8, 'max_delta_step': 7}. Best is trial 8 with value: 0.9688310995183617.
# [I 2024-08-22 19:10:06,319] Trial 12 finished with value: 0.9623473822671768 and parameters: {'lambda': 2.0122548586678914, 'alpha': 0.26712653136236003, 'subsample': 0.9954023678879615, 'colsample_bytree': 0.7760271951641782, 'max_depth': 9, 'eta': 0.05760582870455729, 'gamma': 5.831764080941053, 'scale_pos_weight': 3.563800114299333, 'min_child_weight': 7, 'max_delta_step': 6}. Best is trial 8 with value: 0.9688310995183617.
# [I 2024-08-22 19:10:07,166] Trial 13 finished with value: 0.964411558692248 and parameters: {'lambda': 0.012997295559230664, 'alpha': 0.13499504959804548, 'subsample': 0.759149886335931, 'colsample_bytree': 0.7596610887865104, 'max_depth': 7, 'eta': 0.08110783393182908, 'gamma': 8.772736433129039, 'scale_pos_weight': 1.8115451110285257, 'min_child_weight': 10, 'max_delta_step': 4}. Best is trial 8 with value: 0.9688310995183617.
# [I 2024-08-22 19:10:08,108] Trial 14 finished with value: 0.6149654887739574 and parameters: {'lambda': 0.10598153881626403, 'alpha': 1.1331048315033574, 'subsample': 0.7758699587632343, 'colsample_bytree': 0.4945236181886933, 'max_depth': 9, 'eta': 0.0129122843172354, 'gamma': 2.9370100486363313, 'scale_pos_weight': 3.3367221891213044, 'min_child_weight': 8, 'max_delta_step': 1}. Best is trial 8 with value: 0.9688310995183617.
# [I 2024-08-22 19:10:08,679] Trial 15 finished with value: 0.9659579301870097 and parameters: {'lambda': 0.12960274297804195, 'alpha': 0.01660222847642027, 'subsample': 0.9659922387916997, 'colsample_bytree': 0.8211383455609059, 'max_depth': 7, 'eta': 0.24903579557782057, 'gamma': 5.977980257677059, 'scale_pos_weight': 4.638596874730263, 'min_child_weight': 7, 'max_delta_step': 8}. Best is trial 8 with value: 0.9688310995183617.
# [I 2024-08-22 19:10:09,499] Trial 16 finished with value: 0.9696674954550493 and parameters: {'lambda': 0.008166926044251567, 'alpha': 0.10569110182768643, 'subsample': 0.7562399298301381, 'colsample_bytree': 0.6978070883659584, 'max_depth': 9, 'eta': 0.17351078624579086, 'gamma': 2.8712907387974487, 'scale_pos_weight': 5.9289758144165745, 'min_child_weight': 9, 'max_delta_step': 2}. Best is trial 16 with value: 0.9696674954550493.
# [I 2024-08-22 19:10:10,363] Trial 17 finished with value: 0.9688891715675639 and parameters: {'lambda': 0.007719759377192526, 'alpha': 0.4032766405008389, 'subsample': 0.7593278806796714, 'colsample_bytree': 0.6964141055791511, 'max_depth': 9, 'eta': 0.16977672219101117, 'gamma': 2.7454416440533125, 'scale_pos_weight': 9.431064828337634, 'min_child_weight': 9, 'max_delta_step': 2}. Best is trial 16 with value: 0.9696674954550493.
# [I 2024-08-22 19:10:11,776] Trial 18 finished with value: 0.9698273729424799 and parameters: {'lambda': 0.0070746481555456426, 'alpha': 0.006779314232575127, 'subsample': 0.7398472127863513, 'colsample_bytree': 0.5472511527639714, 'max_depth': 10, 'eta': 0.16788073061800998, 'gamma': 0.11960009341874223, 'scale_pos_weight': 9.953783499709726, 'min_child_weight': 6, 'max_delta_step': 1}. Best is trial 18 with value: 0.9698273729424799.
# [I 2024-08-22 19:10:13,049] Trial 19 finished with value: 0.9715905442588805 and parameters: {'lambda': 0.0011682243706634546, 'alpha': 0.007941254693261795, 'subsample': 0.7271386408078377, 'colsample_bytree': 0.5139658045084176, 'max_depth': 10, 'eta': 0.24660803557077793, 'gamma': 0.2440994622710035, 'scale_pos_weight': 9.857982042883915, 'min_child_weight': 6, 'max_delta_step': 0}. Best is trial 19 with value: 0.9715905442588805.
# [I 2024-08-22 19:10:14,333] Trial 20 finished with value: 0.9708150976375728 and parameters: {'lambda': 0.0013387868255405353, 'alpha': 0.006386773167798162, 'subsample': 0.7096348575239192, 'colsample_bytree': 0.41301336752871226, 'max_depth': 10, 'eta': 0.25229725444879264, 'gamma': 0.25067403592846615, 'scale_pos_weight': 9.983460489600583, 'min_child_weight': 5, 'max_delta_step': 0}. Best is trial 19 with value: 0.9715905442588805.
# [I 2024-08-22 19:10:15,650] Trial 21 finished with value: 0.9708446564414821 and parameters: {'lambda': 0.0010234025661236238, 'alpha': 0.005970300002468378, 'subsample': 0.695358904089867, 'colsample_bytree': 0.41189313091439317, 'max_depth': 10, 'eta': 0.2573521284707522, 'gamma': 0.10965344433504401, 'scale_pos_weight': 9.995111885888335, 'min_child_weight': 5, 'max_delta_step': 0}. Best is trial 19 with value: 0.9715905442588805.
# [I 2024-08-22 19:10:16,961] Trial 22 finished with value: 0.9707868721318459 and parameters: {'lambda': 0.001387932346012163, 'alpha': 0.0010054502862207246, 'subsample': 0.6957967616953841, 'colsample_bytree': 0.4189775021536172, 'max_depth': 10, 'eta': 0.2633004850738573, 'gamma': 0.11378477532590042, 'scale_pos_weight': 9.037122331072977, 'min_child_weight': 4, 'max_delta_step': 0}. Best is trial 19 with value: 0.9715905442588805.
# [I 2024-08-22 19:10:18,101] Trial 23 finished with value: 0.9698476667815195 and parameters: {'lambda': 0.0010195324815257204, 'alpha': 0.0033880933866030725, 'subsample': 0.559281387263296, 'colsample_bytree': 0.4018696951253546, 'max_depth': 10, 'eta': 0.24852923071359406, 'gamma': 1.2208490825715874, 'scale_pos_weight': 9.998497052855326, 'min_child_weight': 5, 'max_delta_step': 0}. Best is trial 19 with value: 0.9715905442588805.
# [I 2024-08-22 19:10:19,236] Trial 24 finished with value: 0.9723827940205402 and parameters: {'lambda': 0.003935102672705956, 'alpha': 0.004904244933678135, 'subsample': 0.4956767663592614, 'colsample_bytree': 0.476842898030516, 'max_depth': 10, 'eta': 0.2962272535363501, 'gamma': 0.6519127374748063, 'scale_pos_weight': 8.205496625755195, 'min_child_weight': 4, 'max_delta_step': 1}. Best is trial 24 with value: 0.9723827940205402.
# [I 2024-08-22 19:10:20,145] Trial 25 finished with value: 0.9699942428134367 and parameters: {'lambda': 0.0047573565556224846, 'alpha': 0.0034181559868427217, 'subsample': 0.4174785698687718, 'colsample_bytree': 0.5273662813111467, 'max_depth': 9, 'eta': 0.29904201049115986, 'gamma': 1.8197392723168893, 'scale_pos_weight': 8.218683001991602, 'min_child_weight': 4, 'max_delta_step': 1}. Best is trial 24 with value: 0.9723827940205402.
# [I 2024-08-22 19:10:21,477] Trial 26 finished with value: 0.9718408589672541 and parameters: {'lambda': 0.0033848205923183183, 'alpha': 0.03508953478411308, 'subsample': 0.49878597348165554, 'colsample_bytree': 0.4689673035622025, 'max_depth': 10, 'eta': 0.2742845508331669, 'gamma': 0.7129527765383501, 'scale_pos_weight': 8.934015816266063, 'min_child_weight': 3, 'max_delta_step': 2}. Best is trial 24 with value: 0.9723827940205402.
# [I 2024-08-22 19:10:22,476] Trial 27 finished with value: 0.9696118995763755 and parameters: {'lambda': 0.003738327119078879, 'alpha': 0.042175050874031804, 'subsample': 0.47451052975542446, 'colsample_bytree': 0.5616407651309689, 'max_depth': 7, 'eta': 0.2809050158040352, 'gamma': 2.1166223202629224, 'scale_pos_weight': 8.917614587452178, 'min_child_weight': 3, 'max_delta_step': 2}. Best is trial 24 with value: 0.9723827940205402.
# [I 2024-08-22 19:10:23,568] Trial 28 finished with value: 0.9695836231783493 and parameters: {'lambda': 0.020144151840266827, 'alpha': 0.016803904773080372, 'subsample': 0.49190174959392785, 'colsample_bytree': 0.46534289720387073, 'max_depth': 8, 'eta': 0.2280919793343757, 'gamma': 0.8442746755467112, 'scale_pos_weight': 7.656112762511764, 'min_child_weight': 3, 'max_delta_step': 3}. Best is trial 24 with value: 0.9723827940205402.
# [I 2024-08-22 19:10:24,317] Trial 29 finished with value: 0.9583355271550182 and parameters: {'lambda': 0.01198752701989409, 'alpha': 0.0020779986495622032, 'subsample': 0.6018439779707143, 'colsample_bytree': 0.46865809226769334, 'max_depth': 5, 'eta': 0.22761368584518557, 'gamma': 0.8857578064883482, 'scale_pos_weight': 6.946304051214747, 'min_child_weight': 2, 'max_delta_step': 1}. Best is trial 24 with value: 0.9723827940205402.
# [I 2024-08-22 19:10:25,201] Trial 30 finished with value: 0.9673528821904721 and parameters: {'lambda': 0.004151871674240187, 'alpha': 0.0098260216741174, 'subsample': 0.4882705240020865, 'colsample_bytree': 0.48913724910995626, 'max_depth': 9, 'eta': 0.2829172237250473, 'gamma': 3.701819556144637, 'scale_pos_weight': 9.17746894201619, 'min_child_weight': 6, 'max_delta_step': 2}. Best is trial 24 with value: 0.9723827940205402.
# [I 2024-08-22 19:10:26,418] Trial 31 finished with value: 0.9703614476804567 and parameters: {'lambda': 0.0017225488810111503, 'alpha': 0.027602317547401143, 'subsample': 0.44766418212780196, 'colsample_bytree': 0.44401098889448676, 'max_depth': 10, 'eta': 0.273535861735754, 'gamma': 0.6255172472955027, 'scale_pos_weight': 8.663386808598343, 'min_child_weight': 4, 'max_delta_step': 1}. Best is trial 24 with value: 0.9723827940205402.
# [I 2024-08-22 19:10:27,437] Trial 32 finished with value: 0.9705345603482164 and parameters: {'lambda': 0.0019345493629741178, 'alpha': 0.005986911732456526, 'subsample': 0.6471399464761565, 'colsample_bytree': 0.5053863579416698, 'max_depth': 10, 'eta': 0.23474150530880222, 'gamma': 2.138421001567009, 'scale_pos_weight': 7.664642470144147, 'min_child_weight': 5, 'max_delta_step': 0}. Best is trial 24 with value: 0.9723827940205402.
# [I 2024-08-22 19:10:28,533] Trial 33 finished with value: 0.9723514592882047 and parameters: {'lambda': 0.003462998339565783, 'alpha': 0.062189410865926734, 'subsample': 0.5250339836012284, 'colsample_bytree': 0.5742883482549556, 'max_depth': 10, 'eta': 0.263236010621839, 'gamma': 1.3505728092026308, 'scale_pos_weight': 9.40213002350314, 'min_child_weight': 2, 'max_delta_step': 1}. Best is trial 24 with value: 0.9723827940205402.
# [I 2024-08-22 19:10:29,493] Trial 34 finished with value: 0.9718846277861379 and parameters: {'lambda': 0.004396306891049932, 'alpha': 0.05754149632053103, 'subsample': 0.5261757934352862, 'colsample_bytree': 0.5692270301289418, 'max_depth': 9, 'eta': 0.2779223277930111, 'gamma': 1.374605950246538, 'scale_pos_weight': 9.305864153768532, 'min_child_weight': 2, 'max_delta_step': 2}. Best is trial 24 with value: 0.9723827940205402.
# [I 2024-08-22 19:10:30,547] Trial 35 finished with value: 0.9723965083286572 and parameters: {'lambda': 0.020446944700758155, 'alpha': 0.05449834529580904, 'subsample': 0.5235953084741003, 'colsample_bytree': 0.5762813856711262, 'max_depth': 9, 'eta': 0.27309391567579067, 'gamma': 1.4947821132112549, 'scale_pos_weight': 8.031489251183077, 'min_child_weight': 2, 'max_delta_step': 4}. Best is trial 35 with value: 0.9723965083286572.
# [I 2024-08-22 19:10:31,418] Trial 36 finished with value: 0.9676185273028902 and parameters: {'lambda': 0.021721760224998044, 'alpha': 0.06446081971445668, 'subsample': 0.5319524365626696, 'colsample_bytree': 0.577501975073593, 'max_depth': 6, 'eta': 0.285342724797218, 'gamma': 1.6333718020768724, 'scale_pos_weight': 7.73966006618292, 'min_child_weight': 1, 'max_delta_step': 4}. Best is trial 35 with value: 0.9723965083286572.
# [I 2024-08-22 19:10:32,332] Trial 37 finished with value: 0.9701236512374903 and parameters: {'lambda': 0.058927727474797804, 'alpha': 0.1777784136341346, 'subsample': 0.5724461873063614, 'colsample_bytree': 0.6337830964494205, 'max_depth': 8, 'eta': 0.26767518959578007, 'gamma': 3.5445693150948037, 'scale_pos_weight': 6.38087079777647, 'min_child_weight': 2, 'max_delta_step': 3}. Best is trial 35 with value: 0.9723965083286572.
# [I 2024-08-22 19:10:33,234] Trial 38 finished with value: 0.9697556045078507 and parameters: {'lambda': 0.005315613578245694, 'alpha': 4.421537569452126, 'subsample': 0.5524625955023944, 'colsample_bytree': 0.6457644973390996, 'max_depth': 9, 'eta': 0.2974358634838554, 'gamma': 2.34728361997531, 'scale_pos_weight': 8.049269521754416, 'min_child_weight': 2, 'max_delta_step': 5}. Best is trial 35 with value: 0.9723965083286572.
# [I 2024-08-22 19:10:34,203] Trial 39 finished with value: 0.9706514251573539 and parameters: {'lambda': 0.010810002499521652, 'alpha': 0.07430501637917901, 'subsample': 0.46209448152610266, 'colsample_bytree': 0.5947246390647184, 'max_depth': 8, 'eta': 0.18911834554549858, 'gamma': 1.4998506396730928, 'scale_pos_weight': 7.2827181319603245, 'min_child_weight': 1, 'max_delta_step': 3}. Best is trial 35 with value: 0.9723965083286572.
# [I 2024-08-22 19:10:35,047] Trial 40 finished with value: 0.9659710972141534 and parameters: {'lambda': 0.04293967266532718, 'alpha': 3.118389049393198, 'subsample': 0.5273619304108552, 'colsample_bytree': 0.551316710832557, 'max_depth': 9, 'eta': 0.21780736476536955, 'gamma': 3.6118791985645853, 'scale_pos_weight': 8.522672091025969, 'min_child_weight': 2, 'max_delta_step': 5}. Best is trial 35 with value: 0.9723965083286572.
# [I 2024-08-22 19:10:36,171] Trial 41 finished with value: 0.9727479982735426 and parameters: {'lambda': 0.002935783108329407, 'alpha': 0.027579602329630987, 'subsample': 0.5113676484103029, 'colsample_bytree': 0.6054249915651231, 'max_depth': 10, 'eta': 0.274586516569574, 'gamma': 0.9076130736949004, 'scale_pos_weight': 9.444512390035673, 'min_child_weight': 3, 'max_delta_step': 2}. Best is trial 41 with value: 0.9727479982735426.
# [I 2024-08-22 19:10:37,438] Trial 42 finished with value: 0.9733190210626863 and parameters: {'lambda': 0.0025553181163573586, 'alpha': 0.01985612949739417, 'subsample': 0.5176755509446556, 'colsample_bytree': 0.622172584810371, 'max_depth': 10, 'eta': 0.2653491115610398, 'gamma': 1.2363578311253725, 'scale_pos_weight': 9.408538095616768, 'min_child_weight': 1, 'max_delta_step': 1}. Best is trial 42 with value: 0.9733190210626863.
# [I 2024-08-22 19:10:38,519] Trial 43 finished with value: 0.9708701374691961 and parameters: {'lambda': 0.002637255084183484, 'alpha': 0.024621578814935048, 'subsample': 0.5867620303951027, 'colsample_bytree': 0.6611589324077719, 'max_depth': 10, 'eta': 0.23701762558959535, 'gamma': 2.44123273835691, 'scale_pos_weight': 9.496002268460044, 'min_child_weight': 1, 'max_delta_step': 1}. Best is trial 42 with value: 0.9733190210626863.
# [I 2024-08-22 19:10:39,688] Trial 44 finished with value: 0.9723673940750076 and parameters: {'lambda': 0.0022723382531006225, 'alpha': 0.01608825998376188, 'subsample': 0.40033601293018717, 'colsample_bytree': 0.6088941192246398, 'max_depth': 10, 'eta': 0.2644818392598343, 'gamma': 0.8900808230500628, 'scale_pos_weight': 8.581015589354626, 'min_child_weight': 3, 'max_delta_step': 1}. Best is trial 42 with value: 0.9733190210626863.
# [I 2024-08-22 19:10:40,735] Trial 45 finished with value: 0.9732758535143246 and parameters: {'lambda': 0.0022733531148815002, 'alpha': 0.01763568326142532, 'subsample': 0.40372556660875336, 'colsample_bytree': 0.6227241500292864, 'max_depth': 10, 'eta': 0.2881585634745328, 'gamma': 0.9737997475294101, 'scale_pos_weight': 8.51548920852851, 'min_child_weight': 3, 'max_delta_step': 4}. Best is trial 42 with value: 0.9733190210626863.
# [I 2024-08-22 19:10:41,645] Trial 46 finished with value: 0.9723678828401189 and parameters: {'lambda': 0.01729328810893825, 'alpha': 0.026116167414702657, 'subsample': 0.43954744019462844, 'colsample_bytree': 0.7198515863465855, 'max_depth': 9, 'eta': 0.2889113378982723, 'gamma': 1.8121928683090047, 'scale_pos_weight': 6.642202034364214, 'min_child_weight': 4, 'max_delta_step': 4}. Best is trial 42 with value: 0.9733190210626863.
# [I 2024-08-22 19:10:42,264] Trial 47 finished with value: 0.958529822957891 and parameters: {'lambda': 0.006569200941753385, 'alpha': 0.011985778522493842, 'subsample': 0.6088756490417858, 'colsample_bytree': 0.6219532114744237, 'max_depth': 4, 'eta': 0.2982350526420412, 'gamma': 4.816554466169582, 'scale_pos_weight': 8.118420120147983, 'min_child_weight': 3, 'max_delta_step': 3}. Best is trial 42 with value: 0.9733190210626863.
# [I 2024-08-22 19:10:43,508] Trial 48 finished with value: 0.9714984591731076 and parameters: {'lambda': 0.20975007115986039, 'alpha': 0.018823722627934473, 'subsample': 0.4529308757135085, 'colsample_bytree': 0.6643476835518165, 'max_depth': 10, 'eta': 0.12816788970290388, 'gamma': 1.0354279920638219, 'scale_pos_weight': 7.3278540655282125, 'min_child_weight': 1, 'max_delta_step': 4}. Best is trial 42 with value: 0.9733190210626863.
# [I 2024-08-22 19:10:44,498] Trial 49 finished with value: 0.9701519549403453 and parameters: {'lambda': 0.7737752474029922, 'alpha': 0.002219022680586445, 'subsample': 0.40519863778946513, 'colsample_bytree': 0.5962675713624929, 'max_depth': 9, 'eta': 0.2147763848564071, 'gamma': 0.49289086745413013, 'scale_pos_weight': 8.742726390705709, 'min_child_weight': 4, 'max_delta_step': 6}. Best is trial 42 with value: 0.9733190210626863.

# %%
print('Best trial:')
trial = study_xgb.best_trial
print('  F1-score: {}'.format(trial.value))
print('  Params: ')
for key, value in trial.params.items():
    print('    {}: {}'.format(key, value))
    
best_params = study_xgb.best_params
best_model_xgb = XGBClassifier(**best_params)
best_model_xgb.fit(X_train_smt, y_train_smt)

# Evaluate on the test set
y_pred = best_model_xgb.predict(X_test_encoded)

report = classification_report(y_test, y_pred)
print(report)
# Out:
# Best trial:
#   F1-score: 0.9733190210626863
#   Params:
#     lambda: 0.0025553181163573586
#     alpha: 0.01985612949739417
#     subsample: 0.5176755509446556
#     colsample_bytree: 0.622172584810371
#     max_depth: 10
#     eta: 0.2653491115610398
#     gamma: 1.2363578311253725
#     scale_pos_weight: 9.408538095616768
#     min_child_weight: 1
#     max_delta_step: 1
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97     11423
#            1       0.67      0.88      0.76      1074
#
#     accuracy                           0.95     12497
#    macro avg       0.83      0.92      0.87     12497
# weighted avg       0.96      0.95      0.95     12497

# %% [markdown]
# ### Model Evaluation : ROC/AUC

# %%
y_pred = best_model_logistic.predict(X_test_encoded)
report = classification_report(y_test, y_pred)                            #### FINAL RESULTS
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.56      0.94      0.70      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.78      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %%
from sklearn.metrics import roc_curve

probabilities = best_model_logistic.predict_proba(X_test_encoded)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, probabilities)

fpr[:10], tpr[:10], thresholds[:10]
# Out:
# (array([0.        , 0.        , 0.        , 0.00008754, 0.00008754,
#         0.00017509, 0.00017509, 0.00026263, 0.00026263, 0.00035017]),
#  array([0.        , 0.0009311 , 0.16294227, 0.16294227, 0.17877095,
#         0.17877095, 0.21880819, 0.21880819, 0.23091248, 0.23091248]),
#  array([2.        , 1.        , 0.9993731 , 0.99936488, 0.9992289 ,
#         0.99921722, 0.99861096, 0.99860937, 0.99824291, 0.99823686]))

# %%
from sklearn.metrics import auc

area = auc(fpr, tpr)
area
# Out:
# 0.9836989666540651

# %%
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % area)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# roc-auc near 1 is very nice, blue line here is a random guess anything below it is not good, but in our case model works well

# %% [markdown]
# ### Model Evaluation : Rankordering, KS statistic, Gini coeff

# %%
probabilities = best_model_logistic.predict_proba(X_test_encoded)[:,1]

df_eval = pd.DataFrame({
    'Default Truth': y_test,
    'Default Probability': probabilities
})
df_eval.head(3)
# Out:
#        Default Truth  Default Probability
# 19205              0                0.541
# 15514              0                0.000
# 30367              0                0.006

# %%
df_eval['Decile'] = pd.qcut(df_eval['Default Probability'], 10, labels=False, duplicates='drop')
df_eval.head(3)
# Out:
#        Default Truth  Default Probability  Decile
# 19205              0                0.541       8
# 15514              0                0.000       2
# 30367              0                0.006       6

# %%
df_eval[df_eval.Decile==8]['Default Probability'].describe()
# Out:
# count   1250.000
# mean       0.487
# std        0.180
# min        0.218
# 25%        0.321
# 50%        0.469
# 75%        0.641
# max        0.818
# Name: Default Probability, dtype: float64

# %%
df_decile = df_eval.groupby('Decile').apply(lambda x: pd.Series({
    'Minimum Probability': x['Default Probability'].min(),
    'Maximum Probability': x['Default Probability'].max(),
    'Events': x['Default Truth'].sum(),
    'Non-events': x['Default Truth'].count() - x['Default Truth'].sum(),    
}))
df_decile.reset_index(inplace=True)
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events
# 0       0                0.000                0.000   0.000    1250.000
# 1       1                0.000                0.000   0.000    1250.000
# 2       2                0.000                0.000   0.000    1249.000
# 3       3                0.000                0.000   0.000    1250.000
# 4       4                0.000                0.001   0.000    1250.000
# 5       5                0.001                0.005   0.000    1249.000
# 6       6                0.005                0.031   5.000    1245.000
# 7       7                0.031                0.218  11.000    1238.000
# 8       8                0.218                0.818 160.000    1090.000
# 9       9                0.818                1.000 898.000     352.000

# %%
df_decile['Event Rate'] = df_decile['Events']*100 / (df_decile['Events']+df_decile['Non-events'])
df_decile['Non-event Rate'] = df_decile['Non-events']*100 / (df_decile['Events']+df_decile['Non-events'])
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       0                0.000                0.000   0.000    1250.000
# 1       1                0.000                0.000   0.000    1250.000
# 2       2                0.000                0.000   0.000    1249.000
# 3       3                0.000                0.000   0.000    1250.000
# 4       4                0.000                0.001   0.000    1250.000
# 5       5                0.001                0.005   0.000    1249.000
# 6       6                0.005                0.031   5.000    1245.000
# 7       7                0.031                0.218  11.000    1238.000
# 8       8                0.218                0.818 160.000    1090.000
# 9       9                0.818                1.000 898.000     352.000
#
#    Event Rate  Non-event Rate
# 0       0.000         100.000
# 1       0.000         100.000
# 2       0.000         100.000
# 3       0.000         100.000
# 4       0.000         100.000
# 5       0.000         100.000
# 6       0.400          99.600
# 7       0.881          99.119
# 8      12.800          87.200
# 9      71.840          28.160

# %%
df_decile = df_decile.sort_values(by='Decile', ascending=False).reset_index(drop=True)
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.818                1.000 898.000     352.000
# 1       8                0.218                0.818 160.000    1090.000
# 2       7                0.031                0.218  11.000    1238.000
# 3       6                0.005                0.031   5.000    1245.000
# 4       5                0.001                0.005   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate
# 0      71.840          28.160
# 1      12.800          87.200
# 2       0.881          99.119
# 3       0.400          99.600
# 4       0.000         100.000
# 5       0.000         100.000
# 6       0.000         100.000
# 7       0.000         100.000
# 8       0.000         100.000
# 9       0.000         100.000

# %%
df_decile['Cum Events'] =  df_decile['Events'].cumsum()
df_decile['Cum Non-events'] =  df_decile['Non-events'].cumsum()
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.818                1.000 898.000     352.000
# 1       8                0.218                0.818 160.000    1090.000
# 2       7                0.031                0.218  11.000    1238.000
# 3       6                0.005                0.031   5.000    1245.000
# 4       5                0.001                0.005   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-events
# 0      71.840          28.160     898.000         352.000
# 1      12.800          87.200    1058.000        1442.000
# 2       0.881          99.119    1069.000        2680.000
# 3       0.400          99.600    1074.000        3925.000
# 4       0.000         100.000    1074.000        5174.000
# 5       0.000         100.000    1074.000        6424.000
# 6       0.000         100.000    1074.000        7674.000
# 7       0.000         100.000    1074.000        8923.000
# 8       0.000         100.000    1074.000       10173.000
# 9       0.000         100.000    1074.000       11423.000

# %%
df_decile['Cum Event Rate'] = df_decile['Cum Events'] * 100 / df_decile['Events'].sum()
df_decile['Cum Non-event Rate'] = df_decile['Cum Non-events']*100 / df_decile['Non-events'].sum()
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.818                1.000 898.000     352.000
# 1       8                0.218                0.818 160.000    1090.000
# 2       7                0.031                0.218  11.000    1238.000
# 3       6                0.005                0.031   5.000    1245.000
# 4       5                0.001                0.005   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-events  Cum Event Rate  \
# 0      71.840          28.160     898.000         352.000          83.613
# 1      12.800          87.200    1058.000        1442.000          98.510
# 2       0.881          99.119    1069.000        2680.000          99.534
# 3       0.400          99.600    1074.000        3925.000         100.000
# 4       0.000         100.000    1074.000        5174.000         100.000
# 5       0.000         100.000    1074.000        6424.000         100.000
# 6       0.000         100.000    1074.000        7674.000         100.000
# 7       0.000         100.000    1074.000        8923.000         100.000
# 8       0.000         100.000    1074.000       10173.000         100.000
# 9       0.000         100.000    1074.000       11423.000         100.000
#
#    Cum Non-event Rate
# 0               3.082
# 1              12.624
# 2              23.461
# 3              34.361
# 4              45.295
# 5              56.237
# 6              67.180
# 7              78.114
# 8              89.057
# 9             100.000

# %%
df_decile['KS'] = abs(df_decile['Cum Event Rate'] - df_decile['Cum Non-event Rate'])
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.818                1.000 898.000     352.000
# 1       8                0.218                0.818 160.000    1090.000
# 2       7                0.031                0.218  11.000    1238.000
# 3       6                0.005                0.031   5.000    1245.000
# 4       5                0.001                0.005   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-events  Cum Event Rate  \
# 0      71.840          28.160     898.000         352.000          83.613
# 1      12.800          87.200    1058.000        1442.000          98.510
# 2       0.881          99.119    1069.000        2680.000          99.534
# 3       0.400          99.600    1074.000        3925.000         100.000
# 4       0.000         100.000    1074.000        5174.000         100.000
# 5       0.000         100.000    1074.000        6424.000         100.000
# 6       0.000         100.000    1074.000        7674.000         100.000
# 7       0.000         100.000    1074.000        8923.000         100.000
# 8       0.000         100.000    1074.000       10173.000         100.000
# 9       0.000         100.000    1074.000       11423.000         100.000
#
#    Cum Non-event Rate     KS
# 0               3.082 80.531
# 1              12.624 85.887
# 2              23.461 76.073
# 3              34.361 65.639
# 4              45.295 54.705
# 5              56.237 43.763
# 6              67.180 32.820
# 7              78.114 21.886
# 8              89.057 10.943
# 9             100.000  0.000

# %% [markdown]
# To assess whether rank ordering is followed, we should look at whether higher deciles (those with higher predicted probabilities) have higher event rates compared to lower deciles. Rank ordering means that as you move from the top decile to the bottom decile, the event rate should generally decrease.
#
# Non-Events - termed as good (customers) who do not default. Events - termed as bad (customers) who default.
#
# Events and Non-Events terms are interchanged based on usecase to usecase.
#
# eg: for marketing usecase, which customer to reach out (who will take loan based on offers) will be events - here it will termed as good, and the customers who will not take loans will be non-events (bad).
#
# Insights from the Decile Table
#
# Top Deciles
# The first decile (Decile 9) has a high event rate of 72.00% and a non-event rate of 28.00%. This indicates that the model is highly confident in predicting events in this decile.
# The second decile (Decile 8) also shows a significant event rate of 12.72%, with a cumulative event rate reaching 98.6%.
# Middle Deciles:
# Deciles 7 and 6 show a significant drop in event rates
# Lower Deciles:
# Deciles 5 to 0 show zero events, with all predictions being non-events. These deciles collectively have a non-event rate of 100%.
# KS Statistic:
# The KS statistic, which is the maximum difference between cumulative event rates and cumulative non-event rates, is highest at Decile 8 with a value of 85.98%. This suggests that the model performs best at distinguishing between events and non-events up to this decile.
#
# The KS value gradually decreases in the following deciles, indicating a decrease in model performance for distinguishing between events and non-events.
#
# KS Value
#
# The highest KS value is 85.88%, found at Decile 8. This indicates that the model's performance in distinguishing between events and non-events is most significant at this decile. (If KS is in top 3 decile and score above 40, it is considered a good predictive model.)

# %%
gini_coefficient = 2 * area - 1

print("AUC:", area)
print("Gini Coefficient:", gini_coefficient)
# Out:
# AUC: 0.9836989666540651
# Gini Coefficient: 0.9673979333081302

# %% [markdown]
# AUC of 0.98: The model is very good at distinguishing between events and non-events.
#
# Gini coefficient of 0.96: This further confirms that the model is highly effective in its predictions, with almost perfect rank ordering capability.
#
# The Gini coefficient ranges from -1 to 1, where a value closer to 1 signifies a perfect model, 0 indicates a model with no discriminative power, and -1 signifies a perfectly incorrect model.

# %% [markdown]
# ### Finalize The Model and Visualize Feature Importance¶

# %%
final_model = best_model_logistic

feature_importance = final_model.coef_[0]

# Create a DataFrame for easier handling
coef_df = pd.DataFrame(feature_importance, index=X_train_encoded.columns, columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in Logistic Regression')
plt.show()

# %% [markdown]
# ### Save the Model

# %%
X_test_encoded.head(2)
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 19205 0.346               0.755                    0.333
# 15514 0.481               0.226                    1.000
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 19205                     0.990           0.550              0.000
# 15514                     0.323           0.220              0.000
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 19205                    0.000                     1                      0
# 15514                    0.000                     1                      0
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 19205                       0                  1                      0
# 15514                       1                  0                      0
#
#        loan_type_Unsecured
# 19205                    0
# 15514                    0

# %%
X_test_encoded.columns
# Out:
# Index(['age', 'loan_tenure_months', 'number_of_open_accounts',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency', 'residence_type_Owned',
#        'residence_type_Rented', 'loan_purpose_Education', 'loan_purpose_Home',
#        'loan_purpose_Personal', 'loan_type_Unsecured'],
#       dtype='object')

# %%
cols_to_scale
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
X_train_encoded.columns
# Out:
# Index(['age', 'loan_tenure_months', 'number_of_open_accounts',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency', 'residence_type_Owned',
#        'residence_type_Rented', 'loan_purpose_Education', 'loan_purpose_Home',
#        'loan_purpose_Personal', 'loan_type_Unsecured'],
#       dtype='object')

# %%
import os
from joblib import dump

# %%
os.makedirs('artifacts', exist_ok=True)

# %%
from joblib import dump

model_data = {
    'model': final_model,
    'features': X_train_encoded.columns,
    'scaler': scaler,
    'cols_to_scale': cols_to_scale
}
dump(model_data, 'artifacts/model_data.joblib')
# Out:
# ['artifacts/model_data.joblib']

# %%
final_model.coef_, final_model.intercept_
# Out:
# (array([[-0.09205574,  0.62640612,  1.15497012, 15.72229414, 16.87676042,
#          13.51407445,  2.04034217, -1.82004428,  1.82845893,  1.0250881 ,
#          -3.27038082,  1.02978196,  1.02978196]]),
#  array([-20.42138196]))

# %%
MODEL_PATH = 'artifacts/model_data.joblib'

# %%
# Load the model and its components

import joblib
model_data = joblib.load(MODEL_PATH)
model = model_data['model']
scaler = model_data['scaler']
features = model_data['features']
cols_to_scale = model_data['cols_to_scale']

# %%
def prepare_input(age, income, loan_amount, loan_tenure_months, avg_dpd_per_delinquency,
                    delinquency_ratio, credit_utilization_ratio, num_open_accounts, residence_type,
                    loan_purpose, loan_type):
    # Create a dictionary with input values and dummy values for missing features

    input_data = {
        'age': age,
        'loan_tenure_months': loan_tenure_months,
        'number_of_open_accounts': num_open_accounts,
        'credit_utilization_ratio': credit_utilization_ratio,
        'loan_to_income': loan_amount / income if income > 0 else 0,
        'delinquency_ratio': delinquency_ratio,
        'avg_dpd_per_delinquency': avg_dpd_per_delinquency,
        'residence_type_Owned': 1 if residence_type == 'Owned' else 0,
        'residence_type_Rented': 1 if residence_type == 'Rented' else 0,
        'loan_purpose_Education': 1 if loan_purpose == 'Education' else 0,
        'loan_purpose_Home': 1 if loan_purpose == 'Home' else 0,
        'loan_purpose_Personal': 1 if loan_purpose == 'Personal' else 0,
        'loan_type_Unsecured': 1 if loan_type == 'Unsecured' else 0,
        # additional dummy fields just for scaling purpose
        'number_of_dependants': 1,  # Dummy value
        'years_at_current_address': 1,  # Dummy value
        'zipcode': 1,  # Dummy value
        'sanction_amount': 1,  # Dummy value
        'processing_fee': 1,  # Dummy value
        'gst': 1,  # Dummy value
        'net_disbursement': 1,  # Computed dummy value
        'principal_outstanding': 1,  # Dummy value
        'bank_balance_at_application': 1,  # Dummy value
        'number_of_closed_accounts': 1,  # Dummy value
        'enquiry_count': 1  # Dummy value
    }

    # Ensure all columns for features and cols_to_scale are present
    df = pd.DataFrame([input_data])

    # Ensure only required columns for scaling are scaled
    df[cols_to_scale] = scaler.transform(df[cols_to_scale])

    # Ensure the DataFrame contains only the features expected by the model
    df = df[features]

    return df

# %%
def calculate_credit_score(input_df, base_score=300, scale_length=600):
    x = np.dot(input_df.values, model.coef_.T) + model.intercept_

    # Apply the logistic function to calculate the probability
    default_probability = 1 / (1 + np.exp(-x))

    non_default_probability = 1 - default_probability

    # Convert the probability to a credit score, scaled to fit within 300 to 900
    credit_score = base_score + non_default_probability.flatten() * scale_length

    # Determine the rating category based on the credit score
    def get_rating(score):
        if 300 <= score < 500:
            return 'Poor'
        elif 500 <= score < 650:
            return 'Average'
        elif 650 <= score < 750:
            return 'Good'
        elif 750 <= score <= 900:
            return 'Excellent'
        else:
            return 'Undefined'  # in case of any unexpected score

    rating = get_rating(credit_score[0])

    return default_probability.flatten()[0], int(credit_score[0]), rating

# %%
def predict(age, income, loan_amount, loan_tenure_months, avg_dpd_per_delinquency,
            delinquency_ratio, credit_utilization_ratio, num_open_accounts,
            residence_type, loan_purpose, loan_type):

    # Prepare input data
    input_df = prepare_input(age, income, loan_amount, loan_tenure_months, avg_dpd_per_delinquency,
                             delinquency_ratio, credit_utilization_ratio, num_open_accounts, residence_type,
                             loan_purpose, loan_type)

    probability, credit_score, rating = calculate_credit_score(input_df)

    return probability, credit_score, rating

# %%
# Example input values
age = 28
income = 1200000
loan_amount = 2560000
loan_tenure_months = 36
avg_dpd_per_delinquency = 20
delinquency_ratio = 30
credit_utilization_ratio = 30
num_open_accounts = 2
residence_type = 'Owned'
loan_purpose = 'Education'
loan_type = 'Unsecured'

# Predict values
probability, credit_score, rating = predict(age, income, loan_amount, loan_tenure_months,
                                           avg_dpd_per_delinquency, delinquency_ratio,
                                           credit_utilization_ratio, num_open_accounts,
                                           residence_type, loan_purpose, loan_type)

# Print the results
print(f"Probability of Default: {probability:.4f}")
print(f"Credit Score: {credit_score}")
print(f"Rating: {rating}")
# Out:
# Probability of Default: 0.6639
# Credit Score: 501
# Rating: Average
